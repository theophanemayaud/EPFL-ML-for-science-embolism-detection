# %% [markdown]
# # Using https://youtu.be/u1loyDCoGbE for implementation of U-net : https://arxiv.org/pdf/1505.04597.pdf

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.nn.functional as F
import glob
import cv2 as cv
import time

# %%
#Google Collab specifics
from google.colab import drive
drive.mount('/content/drive')
# !cp "/content/drive/MyDrive/helpers.py" .
imgs_names = glob.glob('/content/drive/MyDrive/th_analysedimages/*.tif')
labels_names = glob.glob('/content/drive/MyDrive/labels/*.png')
# Out:
# Mounted at /content/drive

# %%
# #Local github project specifics
# imgs_names = glob.glob( './th_analysedimages/*.tif')
# labels_names = glob.glob('./th_csv_labels/png_masks_emb/*.png')

# %%
imgs_names= sorted(imgs_names)
#imgs = [cv.imread(name, cv.IMREAD_UNCHANGED) for name in imgs_names[1]]
print(f"Found {len(imgs_names)} images")

labels_names= sorted(labels_names)
#labels = [png_to_mask(cv.imread(name, cv.IMREAD_UNCHANGED)) for name in labels_names]
print(f"Found {len(labels_names)} labels")
# Out:
# Found 357 images
# Found 357 labels

# %% [markdown]
# <img src="U-Net structure.png" width="500">

# %%
# UNet definitions
class UNet(nn.Module):
    def __init__(self):
        super(UNet, self).__init__()
        
        # functions for going down the U
        self.max_pool_2x2 = nn.MaxPool2d(kernel_size=2, stride=2)
        self.d_double_conv_1 = double_conv(1, 64)
        self.d_double_conv_2 = double_conv(64, 128)
        self.d_double_conv_3 = double_conv(128, 256)
        self.d_double_conv_4 = double_conv(256, 512)
        self.d_double_conv_5 = double_conv(512, 1024)
        
        # functions for going up the U
        self.up_trans_4 = nn.ConvTranspose2d(in_channels=1024, out_channels=512, kernel_size=2, stride=2)        
        self.u_double_conv_4 = double_conv(1024, 512)
        self.up_trans_3 = nn.ConvTranspose2d(in_channels=512, out_channels=256, kernel_size=2, stride=2)
        self.u_double_conv_3 = double_conv(512, 256)
        self.up_trans_2 = nn.ConvTranspose2d(in_channels=256, out_channels=128, kernel_size=2, stride=2)
        self.u_double_conv_2 = double_conv(256, 128)
        self.up_trans_1 = nn.ConvTranspose2d(in_channels=128, out_channels=64, kernel_size=2, stride=2)
        self.u_double_conv_1 = double_conv(128, 64)
        
        self.out = nn.Conv2d(in_channels=64, out_channels=1, kernel_size=1)
        #self.sigmoid = nn.Sigmoid()
        
    def forward(self, image):
        '''makes the 388x388 prediction with the model, image must be 572x572pixels'''
        
        # Going down the U
        d1 = self.d_double_conv_1(image) # first "level"
        # print(x1.size())
        x = self.max_pool_2x2(d1)
        d2 = self.d_double_conv_2(x) # second
        x = self.max_pool_2x2(d2)
        d3 = self.d_double_conv_3(x) # third
        x = self.max_pool_2x2(d3)
        d4 = self.d_double_conv_4(x) # fourth
        x = self.max_pool_2x2(d4)
        x = self.d_double_conv_5(x) # last layer (fifth) : no max pool
        # plt.imshow(x.detach().numpy()[0, 0, :, :])
        
        # Going up the U
        x = self.up_trans_4(x)
        d4 = crop_img(tensor=d4, target_tensor=x) #crop to copy
        x = self.u_double_conv_4(torch.cat([d4, x], 1))
        
        x = self.up_trans_3(x)
        d3 = crop_img(tensor=d3, target_tensor=x)
        x = self.u_double_conv_3(torch.cat([d3, x], 1))
        
        x = self.up_trans_2(x)
        d2 = crop_img(tensor=d2, target_tensor=x)
        x = self.u_double_conv_2(torch.cat([d2, x], 1))
        
        x = self.up_trans_1(x)
        d1 = crop_img(tensor=d1, target_tensor=x)
        x = self.u_double_conv_1(torch.cat([d1, x], 1))
        
        x = self.out(x)
        #x = self.sigmoid(x) # see https://medium.com/analytics-vidhya/simple-neural-network-with-bceloss-for-binary-classification-for-a-custom-dataset-8d5c69ffffee why necessary
        return x
        
        
    
# some functions so reduce redunduncy
def double_conv(nb_in_channels, nb_out_channels):
    conv = nn.Sequential(
        nn.Conv2d(nb_in_channels, nb_out_channels, kernel_size=3),
        nn.ReLU(inplace=True),
        nn.Conv2d(nb_out_channels, nb_out_channels, kernel_size=3),
        nn.ReLU(inplace=True),
    )
    return conv

def crop_img(tensor, target_tensor):
    target_size = target_tensor.size()[2] # NB they are square so .size[2]=.size[3]
    tensor_size = tensor.size()[2]
    delta = tensor_size - target_size #target is always smaller
    pix_crop = delta // 2
    return tensor[:, :, pix_crop:tensor_size-pix_crop, pix_crop:tensor_size-pix_crop]

# %%
# Test forward to see how it behaves
# image = torch.rand((1, 1, 572, 572))
# print(image.type())
# model = UNet()
# y = model(image).detach().numpy()
# print(f"Output shape : {y.shape}")
# print(f"Output max value : {y[0,0, :, :].max()}, min={y[0,0, :, :].min()}")
# _ , axs = plt.subplots(ncols=2)
# axs[0].imshow(image.detach().numpy()[0,0,:,:])
# axs[0].set_title("Original image")
# axs[1].imshow(y[0,0, :, :])
# axs[1].set_title("Output label image")
# plt.show()

# %%
# Training function
from helpers import png_to_mask, segment_dataset

def train_model(model, img_pathnames, label_pathnames, criterion, optimizer, device, num_epochs=25):
    
    print("Starting the training on images !")
    model.train()
    for epoch in range(num_epochs):
        print(f"\nEpoch {1+epoch}/{num_epochs}", end="")
        
        for image_i in range(len(img_pathnames)):
            image = cv.imread(img_pathnames[image_i], cv.IMREAD_UNCHANGED)
            label = png_to_mask(cv.imread(label_pathnames[image_i], cv.IMREAD_UNCHANGED))
            
            image_segments, label_segments = segment_dataset([image], [label])
            
            for segment_i in range(len(image_segments[:, 0, 0])):
                since = time.process_time()
                img_seg = torch.tensor(image_segments[segment_i, :, :], requires_grad=True).view(1, 1, 572, 572).to(device).float()
                label_seg = torch.tensor(label_segments[segment_i, :, :].astype(float)).view(1, 1, 388, 388).to(device).float()
                # if image_i<1 and epoch<1:
                #     print(img_seg.size())
                #     print(label_seg.size())
                #     _ , axs = plt.subplots(ncols=2)
                #     axs[0].imshow(img_seg.cpu().detach().numpy()[0,0,:,:])
                #     axs[0].set_title("Segment of original image")
                #     axs[1].imshow(label_seg.cpu().detach().numpy()[0,0,:,:])
                #     axs[1].set_title("Segment of original label")
                #     plt.show()
                
                prediction = model(img_seg)
                loss = criterion(prediction, label_seg)
            
                # Compute the gradient
                optimizer.zero_grad()
                loss.backward()
                
                #test
                #print(model.parameters())

                # Update the parameters of the model with a gradient step
                optimizer.step()
            
                time_elapsed = time.process_time()-since
                
                if image_i%10==0:
                    if segment_i==0:
                        print(f"\n|  Image {1+image_i}/{len(img_pathnames)} '{img_pathnames[image_i]}'")
                    if segment_i%3==0:
                        new_prediction = model(img_seg)
                        new_loss = criterion(new_prediction, label_seg)
                        print(f"|  |  Segment {1+segment_i}/{len(image_segments[:, 0, 0])} of image {1+image_i} : loss={loss} segment train time={int(time_elapsed)//60}m {int(time_elapsed%60)}s. Loss reduced by {loss-new_loss} to {new_loss}")
                else:
                    if image_i%10==1 and segment_i==0:
                        print("|  Next images & segments ", end="")
                    print(".", end="")

                if torch.cuda.is_available():
                    del img_seg
                    del label_seg
                    del prediction
                    del loss
                    torch.cuda.empty_cache()

    print("\n\n Finished training")

# %%
# If a GPU is available (ex when on Google Colab)
if not torch.cuda.is_available():
    print("Things will go much quicker if you enable a GPU, ex in Colab under 'Runtime / Change Runtime Type'")
else:
    del model
    torch.cuda.empty_cache()
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

print(f"    Selected device is: {device}/n")
  
learning_rate = 10e-9
model = UNet().to(device)
criterion = torch.nn.MSELoss()
optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate)
train_model(model, imgs_names[:1], labels_names[:1], criterion, optimizer, device, num_epochs=30)
# Out:
#     Selected device is: cuda/n
# Starting the training on images !
#
# Epoch 1/30
# |  Image 1/1 '/content/drive/MyDrive/th_analysedimages/Session1_flushed_1-fs-08_311.tif'
# |  |  Segment 1/6 of image 1 : loss=34572.45703125 segment train time=0m 0s. Loss reduced by -226403.140625 to 260975.59375
# |  |  Segment 4/6 of image 1 : loss=27693.87890625 segment train time=0m 0s. Loss reduced by -25540.65625 to 53234.53515625
#
# Epoch 2/30
# |  Image 1/1 '/content/drive/MyDrive/th_analysedimages/Session1_flushed_1-fs-08_311.tif'
# |  |  Segment 1/6 of image 1 : loss=520.873779296875 segment train time=0m 0s. Loss reduced by 260.9938049316406 to 259.8799743652344
# |  |  Segment 4/6 of image 1 : loss=126.29586029052734 segment train time=0m 0s. Loss reduced by 21.63636016845703 to 104.65950012207031
#
# Epoch 3/30
# |  Image 1/1 '/content/drive/MyDrive/th_analysedimages/Session1_flushed_1-fs-08_311.tif'
# |  |  Segment 1/6 of image 1 : loss=74.03770446777344 segment train time=0m 0s. Loss reduced by 1.4789199829101562 to 72.55878448486328
# |  |  Segment 4/6 of image 1 : loss=87.0735092163086 segment train time=0m 0s. Loss reduced by 1.3822097778320312 to 85.69129943847656
#
# Epoch 4/30
# |  Image 1/1 '/content/drive/MyDrive/th_analysedimages/Session1_flushed_1-fs-08_311.tif'
# |  |  Segment 1/6 of image 1 : loss=66.92724609375 segment train time=0m 0s. Loss reduced by 0.763214111328125 to 66.16403198242188
# |  |  Segment 4/6 of image 1 : loss=79.88823699951172 segment train time=0m 0s. Loss reduced by 1.09686279296875 to 78.79137420654297
#
# Epoch 5/30
# |  Image 1/1 '/content/drive/MyDrive/th_analysedimages/Session1_flushed_1-fs-08_311.tif'
# |  |  Segment 1/6 of image 1 : loss=61.80924606323242 segment train time=0m 0s. Loss reduced by 0.6377067565917969 to 61.171539306640625
# |  |  Segment 4/6 of image 1 : loss=73.93383026123047 segment train time=0m 0s. Loss reduced by 0.9353179931640625 to 72.9985122680664
#
# Epoch 6/30
# |  Image 1/1 '/content/drive/MyDrive/th_analysedimages/Session1_flushed_1-fs-08_311.tif'
# |  |  Segment 1/6 of image 1 : loss=57.481201171875 segment train time=0m 0s. Loss reduced by 0.5424957275390625 to 56.93870544433594
# |  |  Segment 4/6 of image 1 : loss=68.85653686523438 segment train time=0m 0s. Loss reduced by 0.7955780029296875 to 68.06095886230469
#
# Epoch 7/30
# |  Image 1/1 '/content/drive/MyDrive/th_analysedimages/Session1_flushed_1-fs-08_311.tif'
# |  |  Segment 1/6 of image 1 : loss=53.80683898925781 segment train time=0m 0s. Loss reduced by 0.45782470703125 to 53.34901428222656
# |  |  Segment 4/6 of image 1 : loss=64.55297088623047 segment train time=0m 0s. Loss reduced by 0.6722297668457031 to 63.880741119384766
#
# Epoch 8/30
# |  Image 1/1 '/content/drive/MyDrive/th_analysedimages/Session1_flushed_1-fs-08_311.tif'
# |  |  Segment 1/6 of image 1 : loss=50.7144889831543 segment train time=0m 0s. Loss reduced by 0.38437652587890625 to 50.33011245727539
# |  |  Segment 4/6 of image 1 : loss=60.95013427734375 segment train time=0m 0s. Loss reduced by 0.556121826171875 to 60.394012451171875
#
# Epoch 9/30
# |  Image 1/1 '/content/drive/MyDrive/th_analysedimages/Session1_flushed_1-fs-08_311.tif'
# |  |  Segment 1/6 of image 1 : loss=48.14638137817383 segment train time=0m 0s. Loss reduced by 0.31678009033203125 to 47.8296012878418
# |  |  Segment 4/6 of image 1 : loss=57.970802307128906 segment train time=0m 0s. Loss reduced by 0.461639404296875 to 57.50916290283203
#
# Epoch 10/30
# |  Image 1/1 '/content/drive/MyDrive/th_analysedimages/Session1_flushed_1-fs-08_311.tif'
# |  |  Segment 1/6 of image 1 : loss=46.02334976196289 segment train time=0m 0s. Loss reduced by 0.26253509521484375 to 45.76081466674805
# |  |  Segment 4/6 of image 1 : loss=55.496559143066406 segment train time=0m 0s. Loss reduced by 0.3845367431640625 to 55.112022399902344
#
# Epoch 11/30
# |  Image 1/1 '/content/drive/MyDrive/th_analysedimages/Session1_flushed_1-fs-08_311.tif'
# |  |  Segment 1/6 of image 1 : loss=44.25992965698242 segment train time=0m 0s. Loss reduced by 0.2202911376953125 to 44.03963851928711
# |  |  Segment 4/6 of image 1 : loss=53.42399215698242 segment train time=0m 0s. Loss reduced by 0.3268280029296875 to 53.097164154052734
#
# Epoch 12/30
# |  Image 1/1 '/content/drive/MyDrive/th_analysedimages/Session1_flushed_1-fs-08_311.tif'
# |  |  Segment 1/6 of image 1 : loss=42.77068328857422 segment train time=0m 0s. Loss reduced by 0.18883895874023438 to 42.581844329833984
# |  |  Segment 4/6 of image 1 : loss=51.651485443115234 segment train time=0m 0s. Loss reduced by 0.2828330993652344 to 51.36865234375
#
# Epoch 13/30
# |  Image 1/1 '/content/drive/MyDrive/th_analysedimages/Session1_flushed_1-fs-08_311.tif'
# |  |  Segment 1/6 of image 1 : loss=41.48758316040039 segment train time=0m 0s. Loss reduced by 0.16400146484375 to 41.32358169555664
# |  |  Segment 4/6 of image 1 : loss=50.112648010253906 segment train time=0m 0s. Loss reduced by 0.24826812744140625 to 49.8643798828125
#
# Epoch 14/30
# |  Image 1/1 '/content/drive/MyDrive/th_analysedimages/Session1_flushed_1-fs-08_311.tif'
# |  |  Segment 1/6 of image 1 : loss=40.3689079284668 segment train time=0m 0s. Loss reduced by 0.14510345458984375 to 40.22380447387695
# |  |  Segment 4/6 of image 1 : loss=48.760074615478516 segment train time=0m 0s. Loss reduced by 0.2201690673828125 to 48.5399055480957
#
# Epoch 15/30
# |  Image 1/1 '/content/drive/MyDrive/th_analysedimages/Session1_flushed_1-fs-08_311.tif'
# |  |  Segment 1/6 of image 1 : loss=39.37847137451172 segment train time=0m 0s. Loss reduced by 0.13003921508789062 to 39.24843215942383
# |  |  Segment 4/6 of image 1 : loss=47.556888580322266 segment train time=0m 0s. Loss reduced by 0.19659423828125 to 47.360294342041016
#
# Epoch 16/30
# |  Image 1/1 '/content/drive/MyDrive/th_analysedimages/Session1_flushed_1-fs-08_311.tif'
# |  |  Segment 1/6 of image 1 : loss=38.495208740234375 segment train time=0m 0s. Loss reduced by 0.11674880981445312 to 38.37845993041992
# |  |  Segment 4/6 of image 1 : loss=46.48016357421875 segment train time=0m 0s. Loss reduced by 0.17733383178710938 to 46.30282974243164
#
# Epoch 17/30
# |  Image 1/1 '/content/drive/MyDrive/th_analysedimages/Session1_flushed_1-fs-08_311.tif'
# |  |  Segment 1/6 of image 1 : loss=37.70362091064453 segment train time=0m 0s. Loss reduced by 0.10554885864257812 to 37.59807205200195
# |  |  Segment 4/6 of image 1 : loss=45.508548736572266 segment train time=0m 0s. Loss reduced by 0.1606597900390625 to 45.3478889465332
#
# Epoch 18/30
# |  Image 1/1 '/content/drive/MyDrive/th_analysedimages/Session1_flushed_1-fs-08_311.tif'
# |  |  Segment 1/6 of image 1 : loss=36.986228942871094 segment train time=0m 0s. Loss reduced by 0.09700393676757812 to 36.889225006103516
# |  |  Segment 4/6 of image 1 : loss=44.625221252441406 segment train time=0m 0s. Loss reduced by 0.14728164672851562 to 44.47793960571289
#
# Epoch 19/30
# |  Image 1/1 '/content/drive/MyDrive/th_analysedimages/Session1_flushed_1-fs-08_311.tif'
# |  |  Segment 1/6 of image 1 : loss=36.329368591308594 segment train time=0m 0s. Loss reduced by 0.08921432495117188 to 36.24015426635742
# |  |  Segment 4/6 of image 1 : loss=43.815711975097656 segment train time=0m 0s. Loss reduced by 0.13559341430664062 to 43.680118560791016
#
# Epoch 20/30
# |  Image 1/1 '/content/drive/MyDrive/th_analysedimages/Session1_flushed_1-fs-08_311.tif'
# |  |  Segment 1/6 of image 1 : loss=35.72752380371094 segment train time=0m 0s. Loss reduced by 0.08272933959960938 to 35.64479446411133
# |  |  Segment 4/6 of image 1 : loss=43.070465087890625 segment train time=0m 0s. Loss reduced by 0.12541580200195312 to 42.94504928588867
#
# Epoch 21/30
# |  Image 1/1 '/content/drive/MyDrive/th_analysedimages/Session1_flushed_1-fs-08_311.tif'
# |  |  Segment 1/6 of image 1 : loss=35.17034912109375 segment train time=0m 0s. Loss reduced by 0.0778045654296875 to 35.09254455566406
# |  |  Segment 4/6 of image 1 : loss=42.37900161743164 segment train time=0m 0s. Loss reduced by 0.11702346801757812 to 42.26197814941406
#
# Epoch 22/30
# |  Image 1/1 '/content/drive/MyDrive/th_analysedimages/Session1_flushed_1-fs-08_311.tif'
# |  |  Segment 1/6 of image 1 : loss=34.649078369140625 segment train time=0m 0s. Loss reduced by 0.07346343994140625 to 34.57561492919922
# |  |  Segment 4/6 of image 1 : loss=41.73426055908203 segment train time=0m 0s. Loss reduced by 0.1093597412109375 to 41.624900817871094
#
# Epoch 23/30
# |  Image 1/1 '/content/drive/MyDrive/th_analysedimages/Session1_flushed_1-fs-08_311.tif'
# |  |  Segment 1/6 of image 1 : loss=34.160831451416016 segment train time=0m 0s. Loss reduced by 0.06919097900390625 to 34.09164047241211
# |  |  Segment 4/6 of image 1 : loss=41.13140106201172 segment train time=0m 0s. Loss reduced by 0.10280227661132812 to 41.02859878540039
#
# Epoch 24/30
# |  Image 1/1 '/content/drive/MyDrive/th_analysedimages/Session1_flushed_1-fs-08_311.tif'
# |  |  Segment 1/6 of image 1 : loss=33.7033576965332 segment train time=0m 0s. Loss reduced by 0.0654754638671875 to 33.637882232666016
# |  |  Segment 4/6 of image 1 : loss=40.564117431640625 segment train time=0m 0s. Loss reduced by 0.09744644165039062 to 40.466670989990234
#
# Epoch 25/30
# |  Image 1/1 '/content/drive/MyDrive/th_analysedimages/Session1_flushed_1-fs-08_311.tif'
# |  |  Segment 1/6 of image 1 : loss=33.27168273925781 segment train time=0m 0s. Loss reduced by 0.0623016357421875 to 33.209381103515625
# |  |  Segment 4/6 of image 1 : loss=40.027442932128906 segment train time=0m 0s. Loss reduced by 0.092529296875 to 39.934913635253906
#
# Epoch 26/30
# |  Image 1/1 '/content/drive/MyDrive/th_analysedimages/Session1_flushed_1-fs-08_311.tif'
# |  |  Segment 1/6 of image 1 : loss=32.86309051513672 segment train time=0m 0s. Loss reduced by 0.05957794189453125 to 32.80351257324219
# |  |  Segment 4/6 of image 1 : loss=39.51893615722656 segment train time=0m 0s. Loss reduced by 0.08794021606445312 to 39.43099594116211
#
# Epoch 27/30
# |  Image 1/1 '/content/drive/MyDrive/th_analysedimages/Session1_flushed_1-fs-08_311.tif'
# |  |  Segment 1/6 of image 1 : loss=32.474647521972656 segment train time=0m 0s. Loss reduced by 0.057094573974609375 to 32.41755294799805
# |  |  Segment 4/6 of image 1 : loss=39.034942626953125 segment train time=0m 0s. Loss reduced by 0.08405303955078125 to 38.950889587402344
#
# Epoch 28/30
# |  Image 1/1 '/content/drive/MyDrive/th_analysedimages/Session1_flushed_1-fs-08_311.tif'
# |  |  Segment 1/6 of image 1 : loss=32.1043815612793 segment train time=0m 0s. Loss reduced by 0.054744720458984375 to 32.04963684082031
# |  |  Segment 4/6 of image 1 : loss=38.57401657104492 segment train time=0m 0s. Loss reduced by 0.08030319213867188 to 38.49371337890625
#
# Epoch 29/30
# |  Image 1/1 '/content/drive/MyDrive/th_analysedimages/Session1_flushed_1-fs-08_311.tif'
# |  |  Segment 1/6 of image 1 : loss=31.750873565673828 segment train time=0m 0s. Loss reduced by 0.05279731750488281 to 31.698076248168945
# |  |  Segment 4/6 of image 1 : loss=38.1334114074707 segment train time=0m 0s. Loss reduced by 0.07682418823242188 to 38.05658721923828
#
# Epoch 30/30
# |  Image 1/1 '/content/drive/MyDrive/th_analysedimages/Session1_flushed_1-fs-08_311.tif'
# |  |  Segment 1/6 of image 1 : loss=31.4127140045166 segment train time=0m 0s. Loss reduced by 0.05079841613769531 to 31.361915588378906
# |  |  Segment 4/6 of image 1 : loss=37.712181091308594 segment train time=0m 0s. Loss reduced by 0.07396697998046875 to 37.638214111328125
#
#
#  Finished training

# %%
# Test prediction
img_nb = 0
test_seg_i = 0
test_img = cv.imread(imgs_names[img_nb], cv.IMREAD_UNCHANGED) 
test_label = png_to_mask(cv.imread(labels_names[img_nb], cv.IMREAD_UNCHANGED))
test_image_segments, test_label_segments = segment_dataset([test_img], [test_label])
test_img_seg = torch.tensor(test_image_segments[test_seg_i, :, :], requires_grad=True).view(1, 1, 572, 572).to(device).float()
test_label_seg = torch.tensor(test_label_segments[test_seg_i, :, :].astype(float)).view(1, 1, 388, 388).to(device).float()

model.eval()
test_pred = model(test_img_seg)
y_test = test_pred.cpu().detach().numpy()

# %%
# Show predictions
y_test[y_test<0.5] = 0
y_test[y_test>=0.5] = 1

print(f"Output shape : {y_test.shape}")
print(f"Output max value : {y_test[0,0, :, :].max()}, min={y_test[0,0, :, :].min()}")

_ , axs = plt.subplots(ncols=3, figsize=(40, 40))

axs[0].set_title("Original image")
axs[0].imshow(test_img_seg.cpu().detach().numpy()[0,0,:,:])

axs[1].set_title("Original label")
axs[1].imshow(test_label_seg.cpu().detach().numpy()[0,0,:,:])

axs[2].set_title("Model predicted label")
axs[2].imshow(y_test[0,0, :, :])

plt.show()
# Out:
# Output shape : (1, 1, 388, 388)
# Output max value : 1.0, min=0.0

# %%
del model
torch.cuda.empty_cache()
