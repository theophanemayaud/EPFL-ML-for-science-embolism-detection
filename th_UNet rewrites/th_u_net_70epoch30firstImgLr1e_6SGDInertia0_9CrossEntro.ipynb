# %% [markdown]
# # UNet implementation with complementary tools to try different approaches
# Based on https://youtu.be/u1loyDCoGbE for implementation of U-net : https://arxiv.org/pdf/1505.04597.pdf
#
# This notebook is the reference notebook of our implementation, and we will make copies of it, to test different small changes and compare their results.
#
# See cell 6 for general parameters which will change frequently. Otherwise changes will be details here in this cell.
#
# ## Specific test details
#
# See params for train, test and epochs
#
# SGD WITH inertia=0.9 . This SGD is changed from the default notebook Adam in the cell where we launch the training. The original code is commented out (kept for reference)
#
# CrossEntropy loss.
#
# learning rate = see params

# %%
# %matplotlib inline
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import glob
import cv2 as cv
import time
import matplotlib.pyplot as plt
import seaborn as sns

# %%
env = "gcp" # local or colab or gcp
train_or_load = "load" # train or load : Are we training a model, or just loading a pretrained one ?

# %%
# Google Colab specifics
if env == "colab":
    from google.colab import drive
    drive.mount('/content/drive', force_remount=True)
    # !cp "/content/drive/MyDrive/helpers.py" .
    imgs_names = glob.glob( '/content/drive/MyDrive/th_analysedimages/*.tif')
    labels_names = glob.glob('/content/drive/MyDrive/labels/*.png')
elif env == "gcp":
    imgs_names = glob.glob( '/home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/*.tif')
    labels_names = glob.glob('/home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/*.png')
    # !cp "/home/jupyter/cs-433-project-2-ml_fools/helpers.py" .
#Local github project specifics
elif env == "local":
    imgs_names = glob.glob( '/Users/theophanemayaud/Dev/EPFL MA1/Machine Learning/cs-433-project-2-ml_fools/th_analysedimages/*.tif')
    labels_names = glob.glob('/Users/theophanemayaud/Dev/EPFL MA1/Machine Learning/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/*.png')
    # !cp "/Users/theophanemayaud/Dev/EPFL MA1/Machine Learning/cs-433-project-2-ml_fools/helpers.py" .

# %%
from helpers import png_to_mask, segment_dataset, compute_emb_surf_pred_error, confusion, out_predict

imgs_names= sorted(imgs_names)
#imgs = [cv.imread(name, cv.IMREAD_UNCHANGED) for name in imgs_names[1]]
print(f"Found {len(imgs_names)} images")

labels_names= sorted(labels_names)
#labels = [png_to_mask(cv.imread(name, cv.IMREAD_UNCHANGED)) for name in labels_names]
print(f"Found {len(labels_names)} labels")
# Out:
# Found 357 images
# Found 357 labels

# %% [markdown]
# ## General parameters are here :

# %%
# Training configuration parameters
learning_rate = 1e-6

num_epochs= 500
number_of_images = 30
train_img_pathnames = imgs_names[:number_of_images]
train_label_pathnames = labels_names[:number_of_images]

disp_every_x_epoch = 50
disp_every_x_img = 25
max_seg_to_disp = 1    # NB 1 (and not 0) means the first segment is displayed
disp_every_x_seg = 4

print_images_while_training = False

# Testing predictions parameters
# test_img_start = 300
# test_img_stop = 330
# test_img_pathnames = imgs_names[test_img_start:test_img_stop]
# test_label_pathnames = labels_names[test_img_start:test_img_stop]
test_imgs_names = glob.glob( '/home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/Session2*.tif')
test_labels_names = glob.glob('/home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/Session2*.png')
test_imgs_names = sorted(test_imgs_names)
print(f"Found {len(test_imgs_names)} test images")
test_labels_names = sorted(test_labels_names)
print(f"Found {len(test_labels_names)} test labels")
test_img_pathnames = test_imgs_names
test_label_pathnames = test_labels_names

print_each_test_stat = True
print_each_test_img = False

# Saving parameters when in train mode
model_name = "70epoch30firstImgLr1e-6SGDInertia0.9CrossEntro"
model_description = "None"
# Out:
# Found 197 test images
# Found 197 test labels

# %% [markdown]
# UNet picture representation :
#
# <img src="https://lmb.informatik.uni-freiburg.de/people/ronneber/u-net/u-net-architecture.png" width="300">

# %%
# Define the device to train on, if a GPU is available (ex when on Google Colab)
if not torch.cuda.is_available():
    print("Things will go much quicker if you enable a GPU, ex in Colab under 'Runtime / Change Runtime Type'")
else:
    #del model # only needed when re-running multiple times
    torch.cuda.empty_cache()
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Selected device is: {device}\n")
# Out:
# Selected device is: cuda

# %%
# UNet definitions
class UNet(nn.Module):
    def __init__(self):
        super(UNet, self).__init__()
        
        # functions for going down the U
        self.max_pool_2x2 = nn.MaxPool2d(kernel_size=2, stride=2)
        self.d_double_conv_1 = double_conv(1, 64)
        self.d_double_conv_2 = double_conv(64, 128)
        self.d_double_conv_3 = double_conv(128, 256)
        self.d_double_conv_4 = double_conv(256, 512)
        self.d_double_conv_5 = double_conv(512, 1024)
        
        # functions for going up the U
        self.up_trans_4 = nn.ConvTranspose2d(in_channels=1024, out_channels=512, kernel_size=2, stride=2)        
        self.u_double_conv_4 = double_conv(1024, 512)
        self.up_trans_3 = nn.ConvTranspose2d(in_channels=512, out_channels=256, kernel_size=2, stride=2)
        self.u_double_conv_3 = double_conv(512, 256)
        self.up_trans_2 = nn.ConvTranspose2d(in_channels=256, out_channels=128, kernel_size=2, stride=2)
        self.u_double_conv_2 = double_conv(256, 128)
        self.up_trans_1 = nn.ConvTranspose2d(in_channels=128, out_channels=64, kernel_size=2, stride=2)
        self.u_double_conv_1 = double_conv(128, 64)
        
        self.out = nn.Conv2d(in_channels=64, out_channels=2, kernel_size=1)
        
    def forward(self, image):
        '''makes the 388x388 prediction with the model, image must be 572x572pixels'''
        
        # Going down the U
        d1 = self.d_double_conv_1(image) # first "level"
        # print(x1.size())
        x = self.max_pool_2x2(d1)
        d2 = self.d_double_conv_2(x) # second
        x = self.max_pool_2x2(d2)
        d3 = self.d_double_conv_3(x) # third
        x = self.max_pool_2x2(d3)
        d4 = self.d_double_conv_4(x) # fourth
        x = self.max_pool_2x2(d4)
        x = self.d_double_conv_5(x) # last layer (fifth) : no max pool
        # plt.imshow(x.detach().numpy()[0, 0, :, :])
        
        # Going up the U
        x = self.up_trans_4(x)
        d4 = crop_img(tensor=d4, target_tensor=x) #crop to copy
        x = self.u_double_conv_4(torch.cat([d4, x], 1))
        
        x = self.up_trans_3(x)
        d3 = crop_img(tensor=d3, target_tensor=x)
        x = self.u_double_conv_3(torch.cat([d3, x], 1))
        
        x = self.up_trans_2(x)
        d2 = crop_img(tensor=d2, target_tensor=x)
        x = self.u_double_conv_2(torch.cat([d2, x], 1))
        
        x = self.up_trans_1(x)
        d1 = crop_img(tensor=d1, target_tensor=x)
        x = self.u_double_conv_1(torch.cat([d1, x], 1))
        
        x = self.out(x)
        return x
        
        
    
# some functions so reduce redunduncy
def double_conv(nb_in_channels, nb_out_channels): # Used for every descending step
    conv = nn.Sequential(
        nn.Conv2d(nb_in_channels, nb_out_channels, kernel_size=3),
        nn.ReLU(inplace=True),
        nn.Conv2d(nb_out_channels, nb_out_channels, kernel_size=3),
        nn.ReLU(inplace=True),
    )
    return conv

def crop_img(tensor, target_tensor): # Used for copy and crop between descending and ascending
    target_size = target_tensor.size()[2] # NB they are square so .size[2]=.size[3]
    tensor_size = tensor.size()[2]
    delta = tensor_size - target_size #target is always smaller
    pix_crop = delta // 2
    return tensor[:, :, pix_crop:tensor_size-pix_crop, pix_crop:tensor_size-pix_crop]

# %%
# Training function
def train_model(model, img_pathnames, label_pathnames, criterion, optimizer, device, num_epochs=25, 
                disp_every_x_epoch = 1,
                disp_every_x_img = 1,
                max_seg_to_disp = 100, # NB 1 (and not 0) means the first segment is displayed
                disp_every_x_seg = 1):
    points=0 # incrementer for displaying progress
    train_start_time = time.process_time() # For process monitoring

    print("Starting the training on images !")
    model.train()
    for epoch in range(num_epochs):
        
        for image_i in range(len(img_pathnames)):
            image = cv.imread(img_pathnames[image_i], cv.IMREAD_UNCHANGED)
            label = png_to_mask(cv.imread(label_pathnames[image_i], cv.IMREAD_UNCHANGED))
            
            image_segments, label_segments = segment_dataset([image], [label])
            
            for segment_i in range(len(image_segments[:, 0, 0])):
                since = time.process_time() # For process monitoring
                img_seg = torch.tensor(image_segments[segment_i, :, :], requires_grad=True).view(1, 1, 572, 572).to(device).float()
                label_seg = torch.tensor(label_segments[segment_i, :, :].astype(float)).view(1, 388, 388).to(device).long()
                
                prediction = model(img_seg)
                loss = criterion(prediction, label_seg)
            
                # Compute the gradient
                optimizer.zero_grad()
                loss.backward()
                
                # Update the parameters of the model with a gradient step
                optimizer.step()
                            
                # Optionnaly display status during training
                if ( epoch%disp_every_x_epoch==0 and image_i%disp_every_x_img==0 
                        and segment_i%disp_every_x_seg==0 and segment_i<max_seg_to_disp): 
                    if image_i==0 and segment_i==0:
                        print(f"\nEpoch {1+epoch}/{num_epochs}", end="")
                    if segment_i==0:
                        print(f"\n|  Image {1+image_i}/{len(img_pathnames)} '{img_pathnames[image_i]}'", end="")
                
                    time_elapsed = time.process_time()-since

                    # Make new prediction so compare before and after step
                    new_prediction = model(img_seg)
                    new_loss = criterion(new_prediction, label_seg)
                    ori_lab_seg = label_seg.cpu().detach().numpy()[0,:,:].astype(int)
                    pred_lab_seg = torch.argmax(prediction, dim=1).cpu().detach().numpy()[0, :, :]

                    emb_surf_pred_error = compute_emb_surf_pred_error(ori_lab_seg, pred_lab_seg, print_values=False)
                    print(f"\n|  |  Segment {1+segment_i}/{len(image_segments[:, 0, 0])} : loss={loss} "+\
                          f"duration={int(time_elapsed)//60}m {int(time_elapsed%60)}s. Loss reduced {loss-new_loss}. "+\
                          f"Emb surf pred err= {emb_surf_pred_error}%", end="")
                        
                    # # Also optionally print confusion values :
                    # print(f"\n|  |  Confusion values are :{confusion(ori_lab_seg, pred_lab_seg, data_type='numpy')}")

                    # Also optionnaly print image segment, label and prediction
                    if print_images_while_training == True:
                        _ , axs = plt.subplots(ncols=3, figsize=(40, 40))
                        axs[0].set_title("Segment of original image")
                        axs[0].imshow(img_seg.cpu().detach().numpy()[0,0,:,:])
                        axs[1].set_title("Segment of original label")
                        axs[1].imshow(label_seg.cpu().detach().numpy()[0,:,:])
                        axs[2].set_title("Predicted label segment")
                        axs[2].imshow(torch.argmax(prediction, dim=1).cpu().detach().numpy()[0,:,:])
                        plt.show()

                    points=0

                if ( (epoch%disp_every_x_epoch==0 and image_i%disp_every_x_img==1 and segment_i==0) 
                        or (epoch%disp_every_x_epoch==1 and points==0) ):
                    print("\n   ...Next epochs & images ", end="")
                    points = 1
                else:
                    print(".", end="")
                    points = points+1 
                    if  points>80:
                        print("\n      ...", end="")
                        points = 1

    time_elapsed = time.process_time()-train_start_time
    print(f"\n\n Finished training after {int(time_elapsed)//60}m {int(time_elapsed%60)}s")

# %%
# Actually training the model
if train_or_load == "train" : 
    
    model = UNet().to(device)
    criterion = torch.nn.CrossEntropyLoss()
    # optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
    optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate, momentum=0.9)
    train_model(model, train_img_pathnames, train_label_pathnames, criterion, optimizer, device, num_epochs,
                disp_every_x_epoch,
                disp_every_x_img,
                max_seg_to_disp,
                disp_every_x_seg)

# %%
# Loading the pre-trained model
if train_or_load == "load":  
    PATH = "/content/drive/MyDrive/savedmodels/" + model_name + ".pkl"
    if env == "local" or env == "gcp":
        PATH = "./savedmodels/" + model_name + ".pkl"

    if device == "cuda":
        map_to_device = "cuda:0"
    else:
        map_to_device = "cpu"

    model = UNet()

    checkpoint = torch.load(PATH)

    print("Model parameters are :")
    print(f"   name : {checkpoint['name']}")
    print(f"   description : {checkpoint['description']}")
    model.load_state_dict(checkpoint['model_state_dict'])
    # # If wanting to resume training :
    # optimizer = TheOptimizerClass(*args, **kwargs)
    # optimizer.load_state_dict(checkpoint['optimizer_state_dict'])

    model.to(device)
    print("Model successfully loaded !")
# Out:
# Model parameters are :
#    name : 70epoch30firstImgLr1e-6SGDInertia0.9CrossEntro
#    description : None
# Model successfully loaded !

# %%
# Test predictions
import pandas as pd
def test_predictions(model, test_img_pathnames, test_label_pathnames):
    emb_surf_pred_errors_list = []
    emb_surf_TP_list = []
    emb_surf_FN_list = []

    print("Starting testing predictions \n")

    for img_i in range(len(test_img_pathnames)):
        test_img = cv.imread(test_img_pathnames[img_i], cv.IMREAD_UNCHANGED)
        test_label = png_to_mask(cv.imread(test_label_pathnames[img_i], cv.IMREAD_UNCHANGED))

        pred_label = out_predict(model, test_img, device)

        emb_surf_pred_error = compute_emb_surf_pred_error(test_label, pred_label, print_values=False)
        
        TP, _, _, FN = confusion(pred_label, test_label, data_type='numpy')
        emb_surf_TP_list.append(TP)
        emb_surf_FN_list.append(FN)
        
        if print_each_test_stat == True:
            print(f"Emb surf pred err={emb_surf_pred_error}%")
            print(f"Confusion values are :{confusion(pred_label, test_label, data_type='numpy')}")
        else:
            print(".", end="")
        emb_surf_pred_errors_list.append(emb_surf_pred_error)

        if img_i == len(test_img_pathnames)-1 or print_each_test_img == True:
            print("\nLast image looks like :")
            _ , axs = plt.subplots(ncols=3, figsize=(40, 40))

            axs[0].set_title("Original image")
            axs[0].imshow(test_img)

            axs[1].set_title("Original label")
            axs[1].imshow(test_label)

            axs[2].set_title("Model predicted label")
            axs[2].imshow(pred_label)
            plt.show()

    # Draw histogram with boxplot of surface error values
    sns.set(style="ticks")
    f, (ax_box, ax_hist) = plt.subplots(2, sharex=True, 
                                        gridspec_kw={"height_ratios": (.15, .85)})
    f.suptitle(f"Surface error distribution for {len(test_img_pathnames)} test images")
    sns.boxplot(x=emb_surf_pred_errors_list, ax=ax_box)
    sns.histplot(x=emb_surf_pred_errors_list, ax=ax_hist)
    ax_box.set(yticks=[])
    sns.despine(ax=ax_hist)
    sns.despine(ax=ax_box, left=True)
    plt.show()
    plt.style.use('default')

    print(f"Finished testing with mean surface error={np.mean(emb_surf_pred_errors_list)}%")
    df = pd.DataFrame(data={"Emb_surf_pred_err":emb_surf_pred_errors_list, "TP": emb_surf_TP_list, "TN": emb_surf_FN_list})
    df.to_csv(f"./{model_name}.csv", sep=',',index=False)
    print("Saved CSV !")
    
test_predictions(model, test_img_pathnames, test_label_pathnames)

if train_or_load == "train":
    print("\n\nCheck of performance on training set :")
    test_predictions(model, train_img_pathnames, train_label_pathnames)
# Out:
# Starting testing predictions
#
# Emb surf pred err=-91.44022576312125%
# Confusion values are :(0.35961840512912946, 0.993063143204756, 0.006936856795244051, 0.6403815948708705)
# Emb surf pred err=64.15869820499915%
# Confusion values are :(0.804185539339037, 0.9842844369724617, 0.015715563027538244, 0.19581446066096292)
# Emb surf pred err=-29.999893147552545%
# Confusion values are :(0.5227719191537279, 0.991974352186892, 0.008025647813107996, 0.4772280808462721)
# Emb surf pred err=-0.5475587011620678%
# Confusion values are :(0.5605098570783097, 0.9921248121488105, 0.007875187851189498, 0.4394901429216903)
# Emb surf pred err=37.0746361423318%
# Confusion values are :(0.7604668427685987, 0.9858414254065263, 0.01415857459347371, 0.2395331572314014)
# Emb surf pred err=69.47735577455431%
# Confusion values are :(0.8136419001218027, 0.9863587214826351, 0.01364127851736488, 0.18635809987819732)
# Emb surf pred err=16.673545191910854%
# Confusion values are :(0.6055509698720595, 0.9948206017967436, 0.005179398203256384, 0.3944490301279406)
# Emb surf pred err=-12.137603611316496%
# Confusion values are :(0.4069614103275958, 0.9932816512614338, 0.0067183487385663035, 0.5930385896724042)
# Emb surf pred err=-3.2701894317048854%
# Confusion values are :(0.3562463796099633, 0.9946923487779845, 0.0053076512220155345, 0.6437536203900367)
# Emb surf pred err=21.25607533414338%
# Confusion values are :(0.6146719319562576, 0.9929615302436063, 0.007038469756393672, 0.3853280680437424)
# Emb surf pred err=29.766199064796258%
# Confusion values are :(0.5396793587174349, 0.993156612671032, 0.006843387328968088, 0.4603206412825651)
# Emb surf pred err=21.52465073317169%
# Confusion values are :(0.5237847823576954, 0.9898754368080175, 0.010124563191982513, 0.47621521764230457)
# Emb surf pred err=-14.433889602053915%
# Confusion values are :(0.3879116934398277, 0.9960367198092649, 0.003963280190735146, 0.6120883065601723)
# Emb surf pred err=-1.2730650677701305%
# Confusion values are :(0.40555358669140484, 0.9903683339308841, 0.009631666069115969, 0.5944464133085952)
# Emb surf pred err=56.67088429635878%
# Confusion values are :(0.6309574019401096, 0.9911857754094258, 0.008814224590574236, 0.3690425980598903)
# Emb surf pred err=-14.427302761191768%
# Confusion values are :(0.028554022196911503, 0.9864853076683334, 0.013514692331666599, 0.9714459778030885)
# Emb surf pred err=20.716766601579376%
# Confusion values are :(0.6859048573551519, 0.9867867594271255, 0.01321324057287453, 0.314095142644848)
# Emb surf pred err=61.341215979850276%
# Confusion values are :(0.7106625620933325, 0.9852053230108079, 0.014794676989192077, 0.2893374379066676)
# Emb surf pred err=131.6630168749195%
# Confusion values are :(0.8111554811284297, 0.9923587459896003, 0.007641254010399742, 0.18884451887157028)
# Emb surf pred err=38.372314685827405%
# Confusion values are :(0.6650487572402669, 0.9838865264269515, 0.016113473573048515, 0.3349512427597331)
# Emb surf pred err=32.07591653896027%
# Confusion values are :(0.7665448544147118, 0.985242611418064, 0.014757388581935931, 0.23345514558528824)
# Emb surf pred err=89.62588937342208%
# Confusion values are :(0.7167775992655497, 0.9932647709117789, 0.006735229088221147, 0.2832224007344503)
# Emb surf pred err=53.10703743980115%
# Confusion values are :(0.6265340997359018, 0.9916232904894674, 0.00837670951053257, 0.3734659002640982)
# Emb surf pred err=67.5925925925926%
# Confusion values are :(0.7138203017832647, 0.9925079680450349, 0.007492031954965023, 0.2861796982167353)
# Emb surf pred err=88.86188740380722%
# Confusion values are :(0.6460105305791819, 0.9893229393238093, 0.010677060676190642, 0.35398946942081816)
# Emb surf pred err=39.51224309174943%
# Confusion values are :(0.5223719146425411, 0.9882246172503055, 0.011775382749694504, 0.47762808535745893)
# Emb surf pred err=-19.763607913267016%
# Confusion values are :(0.39121812370220016, 0.9927865442882288, 0.007213455711771245, 0.6087818762977999)
# Emb surf pred err=12.821207758109596%
# Confusion values are :(0.5583636825611925, 0.9893459784322649, 0.010654021567735109, 0.4416363174388075)
# Emb surf pred err=57.5492341356674%
# Confusion values are :(0.670980958145165, 0.9900626124976407, 0.009937387502359285, 0.32901904185483494)
# Emb surf pred err=33.489750555692765%
# Confusion values are :(0.6544473062131744, 0.9922215365752336, 0.007778463424766376, 0.3455526937868257)
# Emb surf pred err=-8.185797475280415%
# Confusion values are :(0.3996170727742355, 0.9915609215764141, 0.00843907842358596, 0.6003829272257645)
# Emb surf pred err=14.424909976699851%
# Confusion values are :(0.4652134563170361, 0.9899007198633305, 0.010099280136669497, 0.534786543682964)
# Emb surf pred err=85.1951698960966%
# Confusion values are :(0.8239820275203594, 0.9834080453257791, 0.016591954674220963, 0.17601797247964054)
# Emb surf pred err=27.772609587428967%
# Confusion values are :(0.7001490680445187, 0.9853064832305664, 0.014693516769433652, 0.29985093195548135)
# Emb surf pred err=-23.600621544465724%
# Confusion values are :(0.5547742954040463, 0.9947385964105704, 0.005261403589429645, 0.4452257045959537)
# Emb surf pred err=71.62083269319403%
# Confusion values are :(0.8102012597941312, 0.9851552391644725, 0.014844760835527541, 0.1897987402058688)
# Emb surf pred err=72.01593100556987%
# Confusion values are :(0.7866083727615739, 0.9836552647611179, 0.016344735238882174, 0.21339162723842606)
# Emb surf pred err=31.45393526036592%
# Confusion values are :(0.7533398289487929, 0.9868824266827404, 0.013117573317259637, 0.2466601710512071)
# Emb surf pred err=94.64562055091304%
# Confusion values are :(0.6137418755803157, 0.9896046834449876, 0.010395316555012373, 0.3862581244196843)
# Emb surf pred err=61.92893401015228%
# Confusion values are :(0.610644035532995, 0.9927064108108232, 0.0072935891891767884, 0.3893559644670051)
# Emb surf pred err=63.7992125984252%
# Confusion values are :(0.6836614173228347, 0.9933880510298437, 0.006611948970156215, 0.31633858267716536)
# Emb surf pred err=15.308121139068856%
# Confusion values are :(0.6276932348952841, 0.9957352399798931, 0.0042647600201068695, 0.372306765104716)
# Emb surf pred err=-1.3709898546750754%
# Confusion values are :(0.4676764944549635, 0.9951303791474609, 0.004869620852539096, 0.5323235055450365)
# Emb surf pred err=-1479.083094555874%
# Confusion values are :(0.0499001996007984, 0.9999260629204547, 7.393707954530694e-05, 0.9500998003992016)
# Emb surf pred err=19.594677685137363%
# Confusion values are :(0.4607589955483411, 0.9853576027850534, 0.014642397214946689, 0.5392410044516589)
# Emb surf pred err=54.13533834586466%
# Confusion values are :(0.5827067669172933, 0.9883374680624623, 0.011662531937537779, 0.41729323308270677)
# Emb surf pred err=87.42802783758073%
# Confusion values are :(0.7510639363140239, 0.982866595589336, 0.017133404410664042, 0.24893606368597607)
# Emb surf pred err=-34.71199775217758%
# Confusion values are :(0.36246454196562655, 0.9912286616436482, 0.008771338356351755, 0.6375354580343734)
# Emb surf pred err=15.280647004527273%
# Confusion values are :(0.547866027866907, 0.9899825387709886, 0.010017461229011405, 0.45213397213309303)
# Emb surf pred err=-191.0704743810485%
# Confusion values are :(0.20391636919938808, 0.9976103244038727, 0.0023896755961273714, 0.796083630800612)
# Emb surf pred err=45.7087049938147%
# Confusion values are :(0.7475226251709096, 0.9798567411400306, 0.0201432588599694, 0.25247737482909044)
# Emb surf pred err=46.96093380303907%
# Confusion values are :(0.7277985172722015, 0.9894576068165948, 0.010542393183405212, 0.27220148272779854)
# Emb surf pred err=-144.2941243065776%
# Confusion values are :(0.22693885117130477, 0.9962988787088202, 0.0037011212911797937, 0.7730611488286953)
# Emb surf pred err=22.374230458304833%
# Confusion values are :(0.7183011006778185, 0.9868996322935668, 0.013100367706433138, 0.28169889932218145)
# Emb surf pred err=-281.3768359681579%
# Confusion values are :(0.18274290754079084, 0.9992095254667032, 0.0007904745332968754, 0.8172570924592092)
# Emb surf pred err=55.08740709724694%
# Confusion values are :(0.7954220314735336, 0.9757471443342045, 0.024252855665795527, 0.20457796852646637)
# Emb surf pred err=-15883.284457478007%
# Confusion values are :(0.0011192044474616076, 0.9999065145970779, 9.34854029220866e-05, 0.9988807955525384)
# Emb surf pred err=-2528.87537993921%
# Confusion values are :(0.026361429066944154, 0.999918187289545, 8.181271045509738e-05, 0.9736385709330558)
# Emb surf pred err=30.40689516937262%
# Confusion values are :(0.6468230106233714, 0.9958200598882545, 0.004179940111745517, 0.35317698937662856)
# Emb surf pred err=-40010.294117647056%
# Confusion values are :(0.0009532538955087076, 0.9999793238403505, 2.0676159649489866e-05, 0.9990467461044913)
# Emb surf pred err=58.146880758094234%
# Confusion values are :(0.7517767833640432, 0.9958807401076339, 0.004119259892366039, 0.24822321663595684)
# Emb surf pred err=-41.18996365176271%
# Confusion values are :(0.3278512334724687, 0.9940345587964389, 0.005965441203561079, 0.6721487665275313)
# Emb surf pred err=-393.6557961085229%
# Confusion values are :(0.09243067699225581, 0.9985620797081833, 0.0014379202918166462, 0.9075693230077442)
# Emb surf pred err=-373.78715738000255%
# Confusion values are :(0.11236351784453256, 0.9989192831820062, 0.0010807168179937862, 0.8876364821554674)
# Emb surf pred err=-859.884252208346%
# Confusion values are :(0.055818233744803734, 0.99955631314859, 0.0004436868514100304, 0.9441817662551962)
# Emb surf pred err=-24.095865048343963%
# Confusion values are :(0.3982229000547055, 0.9909204308031807, 0.00907956919681927, 0.6017770999452945)
# Emb surf pred err=99.107062729965%
# Confusion values are :(0.595889796284663, 0.9904801299157776, 0.009519870084222361, 0.40411020371533696)
# Emb surf pred err=47.51853402625551%
# Confusion values are :(0.7786754020836926, 0.9787270854850855, 0.02127291451491451, 0.2213245979163075)
# Emb surf pred err=58.30049190230993%
# Confusion values are :(0.777033052383281, 0.9827967632028303, 0.017203236797169674, 0.22296694761671892)
# Emb surf pred err=20.525527773618805%
# Confusion values are :(0.6942805809252882, 0.9909081076300179, 0.00909189236998205, 0.3057194190747118)
# Emb surf pred err=-93.92236976506639%
# Confusion values are :(0.2690720744447371, 0.9959357317997758, 0.004064268200224169, 0.730927925555263)
# Emb surf pred err=-1105.3393922181199%
# Confusion values are :(0.050164938737040525, 0.9992857956452005, 0.000714204354799484, 0.9498350612629595)
# Emb surf pred err=48.46575662116439%
# Confusion values are :(0.7677050519192626, 0.9772953400420682, 0.02270465995793185, 0.23229494808073736)
# Emb surf pred err=63.20154824440144%
# Confusion values are :(0.7961017417749516, 0.991999661305324, 0.00800033869467601, 0.2038982582250484)
# Emb surf pred err=-53.9781081522627%
# Confusion values are :(0.3384261715296198, 0.9960142370690456, 0.003985762930954385, 0.6615738284703802)
# Emb surf pred err=68.29006650933276%
# Confusion values are :(0.7659300579274834, 0.9941357342886662, 0.005864265711333784, 0.23406994207251663)
# Emb surf pred err=-17.946136420840674%
# Confusion values are :(0.5138711054204012, 0.9993470041049033, 0.000652995895096731, 0.4861288945795988)
# Emb surf pred err=70.48619306112816%
# Confusion values are :(0.6381873967429785, 0.9900716480141648, 0.009928351985835155, 0.36181260325702147)
# Emb surf pred err=-248.46572985374246%
# Confusion values are :(0.2128219899596741, 0.9994141982480561, 0.000585801751943841, 0.787178010040326)
# Emb surf pred err=63.464715600660845%
# Confusion values are :(0.6236724097238612, 0.9907329082896499, 0.00926709171035011, 0.37632759027613877)
# Emb surf pred err=-101.58730158730158%
# Confusion values are :(0.3048657379366041, 0.9989309400841024, 0.0010690599158976095, 0.6951342620633959)
# Emb surf pred err=77.99679564985192%
# Confusion values are :(0.7070447152497936, 0.9849220791005784, 0.015077920899421624, 0.2929552847502063)
# Emb surf pred err=79.55602219889006%
# Confusion values are :(0.49291285435728216, 0.9882903641821794, 0.011709635817820597, 0.5070871456427178)
# Emb surf pred err=-1801.4592274678112%
# Confusion values are :(0.036520404478150956, 0.999830846154102, 0.0001691538458979955, 0.963479595521849)
# Emb surf pred err=-261.70588235294116%
# Confusion values are :(0.1992193852658969, 0.9993673701510587, 0.0006326298489413106, 0.8007806147341031)
# Emb surf pred err=-18.81683731513083%
# Confusion values are :(0.5325833014170815, 0.9882554993786989, 0.011744500621301075, 0.4674166985829184)
# Emb surf pred err=43.3645088906907%
# Confusion values are :(0.7404352007240774, 0.9779284980115656, 0.02207150198843442, 0.2595647992759225)
# Emb surf pred err=25.710963496245718%
# Confusion values are :(0.7170247770314568, 0.9849432107195263, 0.015056789280473696, 0.2829752229685432)
# Emb surf pred err=-4.198694294635254%
# Confusion values are :(0.5816198664095105, 0.9891026299350737, 0.010897370064926316, 0.4183801335904896)
# Emb surf pred err=82.1285327861207%
# Confusion values are :(0.7922068836862233, 0.9797716953162887, 0.020228304683711288, 0.2077931163137767)
# Emb surf pred err=21.3625%
# Confusion values are :(0.554, 0.9939891743629231, 0.006010825637076896, 0.446)
# Emb surf pred err=-98.03286276324924%
# Confusion values are :(0.30337735187565734, 0.9990945133809925, 0.0009054866190074502, 0.6966226481243426)
# Emb surf pred err=-246.8821729150727%
# Confusion values are :(0.18351254480286738, 0.9991693498851298, 0.0008306501148701672, 0.8164874551971326)
# Emb surf pred err=45.7089113566894%
# Confusion values are :(0.4217023277686339, 0.9953002714070583, 0.004699728592941709, 0.5782976722313661)
# Emb surf pred err=94.08532643826761%
# Confusion values are :(0.7538784744667097, 0.9916016254770894, 0.008398374522910583, 0.24612152553329025)
# Emb surf pred err=-27888.372093023256%
# Confusion values are :(0.001578728707935189, 0.9999841264907045, 1.587350929559318e-05, 0.9984212712920648)
# Emb surf pred err=7.82198246797033%
# Confusion values are :(0.6761968981793661, 0.9944479279838585, 0.005552072016141549, 0.3238031018206339)
# Emb surf pred err=-2300.103842159917%
# Confusion values are :(0.01903690563752001, 0.9998066479821333, 0.0001933520178667616, 0.98096309436248)
# Emb surf pred err=-510.65019808902355%
# Confusion values are :(0.07957104148379956, 0.9978059422562989, 0.0021940577437010353, 0.9204289585162004)
# Emb surf pred err=3350.0%
# Confusion values are :(0.53148761941899, 0.7554211793442784, 0.2445788206557216, 0.46851238058100997)
# Emb surf pred err=176.391577928364%
# Confusion values are :(0.8124394966118103, 0.9851108263412904, 0.014889173658709525, 0.18756050338818975)
# Emb surf pred err=92.29397869590409%
# Confusion values are :(0.797923073494674, 0.9857695423556532, 0.014230457644346802, 0.20207692650532602)
# Emb surf pred err=83.79160636758321%
# Confusion values are :(0.5340086830680174, 0.9963167331507915, 0.003683266849208445, 0.46599131693198265)
# Emb surf pred err=145.92119439741418%
# Confusion values are :(0.7412651993227644, 0.9874138341262529, 0.01258616587374705, 0.25873480067723564)
# Emb surf pred err=81.1839033099849%
# Confusion values are :(0.5430572723526988, 0.9950542623125472, 0.00494573768745272, 0.4569427276473012)
# Emb surf pred err=95.17923362175526%
# Confusion values are :(0.6514215080346106, 0.9981294419086805, 0.001870558091319508, 0.34857849196538937)
# Emb surf pred err=935.8306188925081%
# Confusion values are :(0.6731813246471227, 0.9883801060119924, 0.01161989398800754, 0.3268186753528773)
# Emb surf pred err=585.5855855855856%
# Confusion values are :(0.8398398398398398, 0.9914579356630475, 0.00854206433695246, 0.16016016016016016)
# Emb surf pred err=533.8709677419355%
# Confusion values are :(0.7565982404692082, 0.9974847379687624, 0.002515262031237612, 0.2434017595307918)
# Emb surf pred err=196.26168224299064%
# Confusion values are :(0.6238317757009346, 0.9987241239983227, 0.0012758760016773755, 0.37616822429906543)
# Emb surf pred err=63.16774658027358%
# Confusion values are :(0.5687544996400288, 0.9910196285955852, 0.008980371404414761, 0.4312455003599712)
# Emb surf pred err=146.59619450317123%
# Confusion values are :(0.7526427061310782, 0.9935424751189271, 0.0064575248810728545, 0.24735729386892177)
# Emb surf pred err=83.8626739261948%
# Confusion values are :(0.6559286146400484, 0.9938601078171349, 0.006139892182865147, 0.3440713853599516)
# Emb surf pred err=137.7248748816448%
# Confusion values are :(0.6684701744893818, 0.9915457328804939, 0.008454267119506115, 0.33152982551061816)
# Emb surf pred err=72.4942110486272%
# Confusion values are :(0.5957657955673172, 0.9957755516627075, 0.0042244483372925285, 0.40423420443268276)
# Emb surf pred err=175.57261676263596%
# Confusion values are :(0.7600767754318618, 0.9870503943585022, 0.012949605641497856, 0.2399232245681382)
# Emb surf pred err=111.88026192703461%
# Confusion values are :(0.4153414405986904, 0.9982406799998841, 0.0017593200001159355, 0.5846585594013096)
# Emb surf pred err=751.0964912280701%
# Confusion values are :(0.7138157894736842, 0.9946670806410003, 0.005332919358999742, 0.28618421052631576)
# Emb surf pred err=125.97056762438683%
# Confusion values are :(0.7081990189208129, 0.9920867413243664, 0.007913258675633597, 0.2918009810791871)
# Emb surf pred err=310.13960323291695%
# Confusion values are :(0.7687974528532941, 0.9890458974241315, 0.01095410257586845, 0.23120254714670585)
# Emb surf pred err=706.7567567567568%
# Confusion values are :(0.3153153153153153, 0.9925843577778065, 0.007415642222193496, 0.6846846846846847)
# Emb surf pred err=882.9865361077111%
# Confusion values are :(0.7711138310893513, 0.9859288552579044, 0.014071144742095558, 0.22888616891064872)
# Emb surf pred err=2213.5135135135133%
# Confusion values are :(0.4594594594594595, 0.9949040485178313, 0.0050959514821687256, 0.5405405405405406)
# Emb surf pred err=298.8988988988989%
# Confusion values are :(0.7287287287287287, 0.9915075029659857, 0.008492497034014316, 0.27127127127127126)
# Emb surf pred err=1.92935589195607%
# Confusion values are :(0.5179578509943603, 0.9987382537701112, 0.0012617462298888185, 0.48204214900563963)
# Emb surf pred err=3.1806814629571742%
# Confusion values are :(0.5012503907471084, 0.9971475604898684, 0.002852439510131643, 0.4987496092528915)
# Emb surf pred err=118.79116621464549%
# Confusion values are :(0.7456412243316544, 0.9960124858200889, 0.00398751417991107, 0.2543587756683456)
# Emb surf pred err=56.87323057565272%
# Confusion values are :(0.6569675998741743, 0.9979884393384509, 0.0020115606615491066, 0.34303240012582575)
# Emb surf pred err=129.09316427783904%
# Confusion values are :(0.7546857772877619, 0.9908070073580229, 0.009192992641977182, 0.24531422271223816)
# Emb surf pred err=214.34370771312584%
# Confusion values are :(0.7448503984363254, 0.9912790538760186, 0.008720946123981426, 0.2551496015636746)
# Emb surf pred err=533.495736906212%
# Confusion values are :(0.7697929354445798, 0.9951103515217412, 0.004889648478258775, 0.23020706455542023)
# Emb surf pred err=140.97811651942953%
# Confusion values are :(0.8012009931289336, 0.987911190491068, 0.01208880950893198, 0.19879900687106647)
# Emb surf pred err=173.83953273901014%
# Confusion values are :(0.8223178604365201, 0.9958116034644148, 0.004188396535585243, 0.17768213956347986)
# Emb surf pred err=174.21052631578948%
# Confusion values are :(0.7652631578947369, 0.9961595170562023, 0.0038404829437976608, 0.23473684210526316)
# Emb surf pred err=257.2326030927835%
# Confusion values are :(0.7061855670103093, 0.9893421903826342, 0.010657809617365887, 0.29381443298969073)
# Emb surf pred err=190.48357535598478%
# Confusion values are :(0.7848583110108558, 0.9871870249562023, 0.01281297504379776, 0.21514168898914424)
# Emb surf pred err=42.49667994687915%
# Confusion values are :(0.3891102257636122, 0.9976312313041894, 0.00236876869581062, 0.6108897742363878)
# Emb surf pred err=568.407960199005%
# Confusion values are :(0.6791044776119403, 0.9940710977065415, 0.005928902293458559, 0.3208955223880597)
# Emb surf pred err=682.4742268041238%
# Confusion values are :(0.7044673539518901, 0.9871876790653766, 0.01281232093462336, 0.29553264604810997)
# Emb surf pred err=333.05288461538464%
# Confusion values are :(0.5612980769230769, 0.992846845860477, 0.007153154139523002, 0.4387019230769231)
# Emb surf pred err=595.7540263543192%
# Confusion values are :(0.6925329428989752, 0.9823445919739893, 0.017655408026010677, 0.3074670571010249)
# Emb surf pred err=200.9090909090909%
# Confusion values are :(0.40606060606060607, 0.9978158388551843, 0.002184161144815732, 0.593939393939394)
# Emb surf pred err=137.04498977505114%
# Confusion values are :(0.7212678936605317, 0.9844114247275455, 0.015588575272454545, 0.2787321063394683)
# Emb surf pred err=1145.8201058201057%
# Confusion values are :(0.7386243386243386, 0.9790763359499721, 0.020923664050027865, 0.2613756613756614)
# Emb surf pred err=218.00347893312718%
# Confusion values are :(0.7097989949748744, 0.9792092994505047, 0.02079070054949524, 0.29020100502512564)
# Emb surf pred err=132.31791400275793%
# Confusion values are :(0.6442271530650621, 0.9867540433646095, 0.01324595663539053, 0.35577284693493794)
# Emb surf pred err=-125.41935483870968%
# Confusion values are :(0.17658843732112192, 0.9977511271480893, 0.0022488728519106382, 0.823411562678878)
# Emb surf pred err=39.475678133050465%
# Confusion values are :(0.6008486134262767, 0.9968098159509202, 0.0031901840490797546, 0.3991513865737233)
# Emb surf pred err=58.244487030689086%
# Confusion values are :(0.7526788847202354, 0.9848347619498642, 0.015165238050135758, 0.24732111527976464)
# Emb surf pred err=-111.86440677966101%
# Confusion values are :(0.1684, 0.9989644304367402, 0.0010355695632597928, 0.8316)
# Emb surf pred err=116.9573520050923%
# Confusion values are :(0.735582431572247, 0.9897978869380528, 0.010202113061947224, 0.26441756842775305)
# Emb surf pred err=284.5837010885555%
# Confusion values are :(0.6985878199470432, 0.9892162026618011, 0.010783797338198937, 0.3014121800529568)
# Emb surf pred err=-446.4466150218929%
# Confusion values are :(0.12493836291913216, 0.9995808165266867, 0.0004191834733133205, 0.8750616370808678)
# Emb surf pred err=65.0294107872786%
# Confusion values are :(0.80249908610548, 0.9870677222290094, 0.012932277770990555, 0.19750091389451996)
# Emb surf pred err=-87.46803069053709%
# Confusion values are :(0.22100954979536153, 0.9996785202384847, 0.0003214797615153629, 0.7789904502046384)
# Emb surf pred err=-2433.521126760563%
# Confusion values are :(0.029575272403824772, 0.9999278874590619, 7.211254093804642e-05, 0.9704247275961753)
# Emb surf pred err=268.24817518248176%
# Confusion values are :(0.6167883211678832, 0.9979460797018881, 0.0020539202981118606, 0.38321167883211676)
# Emb surf pred err=700.9433962264151%
# Confusion values are :(0.10849056603773585, 0.9939064762334383, 0.006093523766561652, 0.8915094339622641)
# Emb surf pred err=4684.126984126984%
# Confusion values are :(0.4656084656084656, 0.9857570069672, 0.014242993032799923, 0.5343915343915344)
# Emb surf pred err=160.8242220353238%
# Confusion values are :(0.6874684608915055, 0.991771519325292, 0.008228480674708032, 0.3125315391084945)
# Emb surf pred err=56.52173913043478%
# Confusion values are :(0.6947648624667259, 0.9969120743872152, 0.0030879256127848303, 0.3052351375332742)
# Emb surf pred err=182.408064745137%
# Confusion values are :(0.6152207865966207, 0.9933853058291541, 0.006614694170845938, 0.3847792134033792)
# Emb surf pred err=46.09676920698717%
# Confusion values are :(0.6034935847889936, 0.9966975872204306, 0.003302412779569454, 0.3965064152110063)
# Emb surf pred err=29.249164309591155%
# Confusion values are :(0.5677552069940859, 0.99593595579658, 0.00406404420341994, 0.4322447930059141)
# Emb surf pred err=266.16130988477863%
# Confusion values are :(0.6901152213462705, 0.9973381630282796, 0.0026618369717204267, 0.30988477865372954)
# Emb surf pred err=-240.2020871293689%
# Confusion values are :(0.17080533644950824, 0.9981365649575478, 0.0018634350424522775, 0.8291946635504918)
# Emb surf pred err=-201.44834245252656%
# Confusion values are :(0.12491992312620115, 0.9982824055190026, 0.001717594480997393, 0.8750800768737989)
# Emb surf pred err=36.02638793694311%
# Confusion values are :(0.4596470185058259, 0.9934430851432111, 0.006556914856788921, 0.5403529814941741)
# Emb surf pred err=162.70043731778426%
# Confusion values are :(0.6927842565597667, 0.990881633901252, 0.009118366098748082, 0.3072157434402332)
# Emb surf pred err=-575.1812604573341%
# Confusion values are :(0.08409053361969271, 0.9992131452462805, 0.0007868547537195385, 0.9159094663803072)
# Emb surf pred err=69.36694422265313%
# Confusion values are :(0.7284361811337972, 0.9818707130884273, 0.01812928691157265, 0.2715638188662028)
# Emb surf pred err=224.54128440366972%
# Confusion values are :(0.8425076452599388, 0.9968395257378043, 0.00316047426219568, 0.15749235474006115)
# Emb surf pred err=445.3501722158439%
# Confusion values are :(0.7026406429391504, 0.9948619506210856, 0.0051380493789143795, 0.2973593570608496)
# Emb surf pred err=553.5019455252918%
# Confusion values are :(0.519455252918288, 0.9958734709020977, 0.004126529097902303, 0.4805447470817121)
# Emb surf pred err=283.2740213523132%
# Confusion values are :(0.3238434163701068, 0.9981474070274525, 0.0018525929725474281, 0.6761565836298933)
# Emb surf pred err=903.5190615835777%
# Confusion values are :(0.6304985337243402, 0.9927744069358484, 0.00722559306415164, 0.36950146627565983)
# Emb surf pred err=-48.10126582278481%
# Confusion values are :(0.1762820512820513, 0.9994993079299117, 0.0005006920700883126, 0.8237179487179487)
# Emb surf pred err=-984.7222222222222%
# Confusion values are :(0.0317406833344565, 0.9994376707910411, 0.000562329208958901, 0.9682593166655435)
# Emb surf pred err=-522.4517906336088%
# Confusion values are :(0.1082097809249834, 0.9997922690790333, 0.00020773092096671133, 0.8917902190750165)
# Emb surf pred err=-118.62776530939404%
# Confusion values are :(0.19079043848071564, 0.9986849319824831, 0.0013150680175168796, 0.8092095615192844)
# Emb surf pred err=213.69216241737487%
# Confusion values are :(0.5819955933270381, 0.9964299019135673, 0.0035700980864327037, 0.4180044066729619)
# Emb surf pred err=-38.93395133256083%
# Confusion values are :(0.3269391159299416, 0.9995510993776389, 0.00044890062236116007, 0.6730608840700584)
# Emb surf pred err=-149.25975773889635%
# Confusion values are :(0.23326133909287258, 0.9995771256236037, 0.0004228743763962673, 0.7667386609071274)
# Emb surf pred err=91.97246888484719%
# Confusion values are :(0.7303234549409793, 0.9679332050738454, 0.03206679492615465, 0.2696765450590207)
# Emb surf pred err=-441.9739022369511%
# Confusion values are :(0.14537672214472705, 0.9990271837539687, 0.0009728162460313088, 0.8546232778552729)
# Emb surf pred err=108.36055442747417%
# Confusion values are :(0.6644301227156352, 0.9879645082144571, 0.012035491785542885, 0.33556987728436477)
# Emb surf pred err=-2682.2128851540615%
# Confusion values are :(0.018776743015353637, 0.9997876393655586, 0.00021236063444140746, 0.9812232569846464)
# Emb surf pred err=157.1873446209405%
# Confusion values are :(0.7979221730824588, 0.9726647292018583, 0.02733527079814168, 0.20207782691754114)
# Emb surf pred err=405.2415210688592%
# Confusion values are :(0.7821171634121274, 0.9906953725433992, 0.009304627456600798, 0.21788283658787255)
# Emb surf pred err=990.6077348066299%
# Confusion values are :(0.3839779005524862, 0.9957672039987643, 0.004232796001235723, 0.6160220994475138)
# Emb surf pred err=293.58288770053474%
# Confusion values are :(0.7292173067574137, 0.9949825881508144, 0.005017411849185545, 0.2707826932425863)
# Emb surf pred err=601.6849816849817%
# Confusion values are :(0.726007326007326, 0.9863605534562424, 0.013639446543757575, 0.273992673992674)
# Emb surf pred err=994.431279620853%
# Confusion values are :(0.7393364928909952, 0.9872354425802398, 0.01276455741976024, 0.26066350710900477)
# Emb surf pred err=-476.47058823529414%
# Confusion values are :(0.04081632653061224, 0.9999693286272437, 3.067137275627111e-05, 0.9591836734693877)
# Emb surf pred err=-89.09698996655518%
# Confusion values are :(0.29731163777856384, 0.9991184775588899, 0.0008815224411100583, 0.7026883622214362)
# Emb surf pred err=-1923.4567901234568%
# Confusion values are :(0.03599755948749237, 0.9999670349264954, 3.296507350462185e-05, 0.9640024405125076)
# Emb surf pred err=174.7890651366858%
# Confusion values are :(0.6798852514343571, 0.984089126855944, 0.015910873144056047, 0.3201147485656429)
#
# Last image looks like :
# Finished testing with mean surface error=-374.6408827724037%
# Saved CSV !

# %%
# Saving the model
if train_or_load == "train":
    print(f"Remember to set a model name that makes it easy to identify")
    print(f"Here are the notebook parameters : \ncriterion={criterion} \noptimizer={optimizer} \nlr={learning_rate}, \nepochs={num_epochs}")
    
    PATH = "/content/drive/MyDrive/savedmodels/" + model_name + ".pkl"
    if env == "local" or env == "gcp":
        PATH = "./savedmodels/" + model_name + ".pkl"

    print("\nmodel_name = " + model_name)
    print("model_description = " + model_description)
    print("PATH = " + PATH)
    # Warning : only save once name and descriptions are set correctly
    torch.save({
            'name': model_name,
            'description': model_description,
            'model_details_dump': f"env={env}, train_or_load={train_or_load}, learning rate={learning_rate}, epochs={num_epochs}, optimizer={optimizer}, criterion={criterion}",         
            'model_state_dict': model.state_dict(),
            # 'optimizer_state_dict': optimizer.state_dict(), # Only needed when planning to resume training from loaded model
            }, PATH)
    print("Model saved !")
# Out:
# Remember to set a model name that makes it easy to identify
# Here are the notebook parameters :
# criterion=CrossEntropyLoss()
# optimizer=SGD (
# Parameter Group 0
#     dampening: 0
#     lr: 1e-06
#     momentum: 0.9
#     nesterov: False
#     weight_decay: 0
# )
# lr=1e-06,
# epochs=500
#
# model_name = 70epoch30firstImgLr1e-6SGDInertia0.9CrossEntro
# model_description = None
# PATH = ./savedmodels/70epoch30firstImgLr1e-6SGDInertia0.9CrossEntro.pkl
# Model saved !
