# %% [markdown]
# # UNet implementation with complementary tools to try different approaches
# Based on https://youtu.be/u1loyDCoGbE for implementation of U-net : https://arxiv.org/pdf/1505.04597.pdf
#
# This notebook is the reference notebook of our implementation, and we will make copies of it, to test different small changes and compare their results.
#
# See cell 6 for general parameters which will change frequently. Otherwise changes will be details here in this cell.
#
# ## Specific test details
#
# Training on 30 first images of dataset, which are all session 1 and all flushed. For 500 epochs at lr=1e-4
#
# Using Adam and CrossEntropy

# %%
# %matplotlib inline
import numpy as np
import torch
import torch.nn as nn
import glob
import cv2 as cv
import time
import matplotlib.pyplot as plt
import seaborn as sns

# %%
env = "gcp" # local or colab or gcp
train_or_load = "load" # train or load : Are we training a model, or just loading a pretrained one ?

# %%
#Google Colab specifics
if env == "colab":
    from google.colab import drive
    drive.mount('/content/drive', force_remount=True)
    # !cp "/content/drive/MyDrive/helpers.py" .
    imgs_names = glob.glob( '/content/drive/MyDrive/th_analysedimages/*.tif')
    labels_names = glob.glob('/content/drive/MyDrive/labels/*.png')
elif env == "gcp":
    imgs_names = glob.glob( '/home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/*.tif')
    labels_names = glob.glob('/home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/*.png')
    # !cp "/home/jupyter/cs-433-project-2-ml_fools/helpers.py" .
#Local github project specifics
elif env == "local":
    imgs_names = glob.glob( '/Users/theophanemayaud/Dev/EPFL MA1/Machine Learning/cs-433-project-2-ml_fools/th_analysedimages/*.tif')
    labels_names = glob.glob('/Users/theophanemayaud/Dev/EPFL MA1/Machine Learning/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/*.png')
    # !cp "/Users/theophanemayaud/Dev/EPFL MA1/Machine Learning/cs-433-project-2-ml_fools/helpers.py" .

# %%
from helpers import png_to_mask, segment_dataset, compute_emb_surf_pred_error, confusion, out_predict

imgs_names= sorted(imgs_names)
#imgs = [cv.imread(name, cv.IMREAD_UNCHANGED) for name in imgs_names[1]]
print(f"Found {len(imgs_names)} images")

labels_names= sorted(labels_names)
#labels = [png_to_mask(cv.imread(name, cv.IMREAD_UNCHANGED)) for name in labels_names]
print(f"Found {len(labels_names)} labels")
# Out:
# Found 357 images
# Found 357 labels

# %% [markdown]
# ## General parameters are here :

# %%
# Training configuration parameters
learning_rate = 1e-4

num_epochs= 500
number_of_images = 30
train_img_pathnames = imgs_names[:number_of_images]
train_label_pathnames = labels_names[:number_of_images]

disp_every_x_epoch = 50
disp_every_x_img = 25
max_seg_to_disp = 1    # NB 1 (and not 0) means the first segment is displayed
disp_every_x_seg = 4

print_images_while_training = False

# Testing predictions parameters
# test_img_start = 300
# test_img_stop = 330
# test_img_pathnames = imgs_names[test_img_start:test_img_stop]
# test_label_pathnames = labels_names[test_img_start:test_img_stop]
test_imgs_names = glob.glob( '/home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/Session2*.tif')
test_labels_names = glob.glob('/home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/Session2*.png')
test_imgs_names = sorted(test_imgs_names)
print(f"Found {len(test_imgs_names)} test images")
test_labels_names = sorted(test_labels_names)
print(f"Found {len(test_labels_names)} test labels")
test_img_pathnames = test_imgs_names
test_label_pathnames = test_labels_names

print_each_test_stat = True
print_each_test_img = False

# Saving parameters when in train mode
model_name = "500epoch30firstImgLr1e-4AdamCrossEntro"
model_description = "None"
# Out:
# Found 197 test images
# Found 197 test labels

# %% [markdown]
# UNet picture representation :
#
# <img src="https://lmb.informatik.uni-freiburg.de/people/ronneber/u-net/u-net-architecture.png" width="300">

# %%
# Define the device to train on, if a GPU is available (ex when on Google Colab)
if not torch.cuda.is_available():
    print("Things will go much quicker if you enable a GPU, ex in Colab under 'Runtime / Change Runtime Type'")
else:
    #del model # only needed when re-running multiple times
    torch.cuda.empty_cache()
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Selected device is: {device}\n")
# Out:
# Selected device is: cuda

# %%
# UNet definitions
class UNet(nn.Module):
    def __init__(self):
        super(UNet, self).__init__()
        
        # functions for going down the U
        self.max_pool_2x2 = nn.MaxPool2d(kernel_size=2, stride=2)
        self.d_double_conv_1 = double_conv(1, 64)
        self.d_double_conv_2 = double_conv(64, 128)
        self.d_double_conv_3 = double_conv(128, 256)
        self.d_double_conv_4 = double_conv(256, 512)
        self.d_double_conv_5 = double_conv(512, 1024)
        
        # functions for going up the U
        self.up_trans_4 = nn.ConvTranspose2d(in_channels=1024, out_channels=512, kernel_size=2, stride=2)        
        self.u_double_conv_4 = double_conv(1024, 512)
        self.up_trans_3 = nn.ConvTranspose2d(in_channels=512, out_channels=256, kernel_size=2, stride=2)
        self.u_double_conv_3 = double_conv(512, 256)
        self.up_trans_2 = nn.ConvTranspose2d(in_channels=256, out_channels=128, kernel_size=2, stride=2)
        self.u_double_conv_2 = double_conv(256, 128)
        self.up_trans_1 = nn.ConvTranspose2d(in_channels=128, out_channels=64, kernel_size=2, stride=2)
        self.u_double_conv_1 = double_conv(128, 64)
        
        self.out = nn.Conv2d(in_channels=64, out_channels=2, kernel_size=1)
        
    def forward(self, image):
        '''makes the 388x388 prediction with the model, image must be 572x572pixels'''
        
        # Going down the U
        d1 = self.d_double_conv_1(image) # first "level"
        # print(x1.size())
        x = self.max_pool_2x2(d1)
        d2 = self.d_double_conv_2(x) # second
        x = self.max_pool_2x2(d2)
        d3 = self.d_double_conv_3(x) # third
        x = self.max_pool_2x2(d3)
        d4 = self.d_double_conv_4(x) # fourth
        x = self.max_pool_2x2(d4)
        x = self.d_double_conv_5(x) # last layer (fifth) : no max pool
        # plt.imshow(x.detach().numpy()[0, 0, :, :])
        
        # Going up the U
        x = self.up_trans_4(x)
        d4 = crop_img(tensor=d4, target_tensor=x) #crop to copy
        x = self.u_double_conv_4(torch.cat([d4, x], 1))
        
        x = self.up_trans_3(x)
        d3 = crop_img(tensor=d3, target_tensor=x)
        x = self.u_double_conv_3(torch.cat([d3, x], 1))
        
        x = self.up_trans_2(x)
        d2 = crop_img(tensor=d2, target_tensor=x)
        x = self.u_double_conv_2(torch.cat([d2, x], 1))
        
        x = self.up_trans_1(x)
        d1 = crop_img(tensor=d1, target_tensor=x)
        x = self.u_double_conv_1(torch.cat([d1, x], 1))
        
        x = self.out(x)
        return x
        
        
    
# some functions so reduce redunduncy
def double_conv(nb_in_channels, nb_out_channels): # Used for every descending step
    conv = nn.Sequential(
        nn.Conv2d(nb_in_channels, nb_out_channels, kernel_size=3),
        nn.ReLU(inplace=True),
        nn.Conv2d(nb_out_channels, nb_out_channels, kernel_size=3),
        nn.ReLU(inplace=True),
    )
    return conv

def crop_img(tensor, target_tensor): # Used for copy and crop between descending and ascending
    target_size = target_tensor.size()[2] # NB they are square so .size[2]=.size[3]
    tensor_size = tensor.size()[2]
    delta = tensor_size - target_size #target is always smaller
    pix_crop = delta // 2
    return tensor[:, :, pix_crop:tensor_size-pix_crop, pix_crop:tensor_size-pix_crop]

# %%
# Training function
def train_model(model, img_pathnames, label_pathnames, criterion, optimizer, device, num_epochs=25, 
                disp_every_x_epoch = 1,
                disp_every_x_img = 1,
                max_seg_to_disp = 100, # NB 1 (and not 0) means the first segment is displayed
                disp_every_x_seg = 1):
    points=0 # incrementer for displaying progress
    train_start_time = time.process_time() # For process monitoring

    print("Starting the training on images !")
    model.train()
    for epoch in range(num_epochs):
        
        for image_i in range(len(img_pathnames)):
            image = cv.imread(img_pathnames[image_i], cv.IMREAD_UNCHANGED)
            label = png_to_mask(cv.imread(label_pathnames[image_i], cv.IMREAD_UNCHANGED))
            
            image_segments, label_segments = segment_dataset([image], [label])
            
            for segment_i in range(len(image_segments[:, 0, 0])):
                since = time.process_time() # For process monitoring
                img_seg = torch.tensor(image_segments[segment_i, :, :], requires_grad=True).view(1, 1, 572, 572).to(device).float()
                label_seg = torch.tensor(label_segments[segment_i, :, :].astype(float)).view(1, 388, 388).to(device).long()
                
                prediction = model(img_seg)
                loss = criterion(prediction, label_seg)
            
                # Compute the gradient
                optimizer.zero_grad()
                loss.backward()
                
                # Update the parameters of the model with a gradient step
                optimizer.step()
                            
                # Optionnaly display status during training
                if ( epoch%disp_every_x_epoch==0 and image_i%disp_every_x_img==0 
                        and segment_i%disp_every_x_seg==0 and segment_i<max_seg_to_disp ): 
                    if image_i==0 and segment_i==0:
                        print(f"\nEpoch {1+epoch}/{num_epochs}", end="")
                    if segment_i==0:
                        print(f"\n|  Image {1+image_i}/{len(img_pathnames)} '{img_pathnames[image_i]}'", end="")
                
                    time_elapsed = time.process_time()-since

                    # Make new prediction so compare before and after step
                    new_prediction = model(img_seg)
                    new_loss = criterion(new_prediction, label_seg)
                    ori_lab_seg = label_seg.cpu().detach().numpy()[0,:,:].astype(int)
                    pred_lab_seg = torch.argmax(prediction, dim=1).cpu().detach().numpy()[0, :, :]

                    emb_surf_pred_error = compute_emb_surf_pred_error(ori_lab_seg, pred_lab_seg, print_values=False)
                    print(f"\n|  |  Segment {1+segment_i}/{len(image_segments[:, 0, 0])} : loss={loss} "+\
                          f"duration={int(time_elapsed)//60}m {int(time_elapsed%60)}s. Loss reduced {loss-new_loss}. "+\
                          f"Emb surf pred err= {emb_surf_pred_error}%", end="")
                        
                    # # Also optionally print confusion values :
                    # print(f"\n|  |  Confusion values are :{confusion(ori_lab_seg, pred_lab_seg, data_type='numpy')}")

                    # Also optionnaly print image segment, label and prediction
                    if print_images_while_training == True:
                        _ , axs = plt.subplots(ncols=3, figsize=(40, 40))
                        axs[0].set_title("Segment of original image")
                        axs[0].imshow(img_seg.cpu().detach().numpy()[0,0,:,:])
                        axs[1].set_title("Segment of original label")
                        axs[1].imshow(label_seg.cpu().detach().numpy()[0,:,:])
                        axs[2].set_title("Predicted label segment")
                        axs[2].imshow(torch.argmax(prediction, dim=1).cpu().detach().numpy()[0,:,:])
                        plt.show()

                    points=0

                if ( (epoch%disp_every_x_epoch==0 and image_i%disp_every_x_img==1 and segment_i==0) 
                        or (epoch%disp_every_x_epoch==1 and points==0) ):
                    print("\n   ...Next epochs & images ", end="")
                    points = 1
                else:
                    print(".", end="")
                    points = points+1 
                    if  points>80:
                        print("\n      ...", end="")
                        points = 1
                        
    time_elapsed = time.process_time()-train_start_time
    print(f"\n\n Finished training after {int(time_elapsed)//60}m {int(time_elapsed%60)}s")

# %%
# Actually training the model
if train_or_load == "train" : 
    
    model = UNet().to(device)
    criterion = torch.nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
    train_model(model, train_img_pathnames, train_label_pathnames, criterion, optimizer, device, num_epochs,
                disp_every_x_epoch,
                disp_every_x_img,
                max_seg_to_disp,
                disp_every_x_seg)

# %%
# Loading the pre-trained model
if train_or_load == "load":  
    PATH = "/content/drive/MyDrive/savedmodels/" + model_name + ".pkl"
    if env == "local" or env == "gcp":
        PATH = "./savedmodels/" + model_name + ".pkl"

    if device == "cuda":
        map_to_device = "cuda:0"
    else:
        map_to_device = "cpu"

    model = UNet()

    checkpoint = torch.load(PATH)

    print("Model parameters are :")
    print(f"   name : {checkpoint['name']}")
    print(f"   description : {checkpoint['description']}")
    model.load_state_dict(checkpoint['model_state_dict'])
    # If wanting to resume training :
#     optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
#     optimizer.load_state_dict(checkpoint['optimizer_state_dict'])

    model.to(device)
    print("Model successfully loaded !")
# Out:
# Model parameters are :
#    name : 500epoch30firstImgLr1e-4AdamCrossEntro.ipynb
#    description : None
# Model successfully loaded !

# %%
# Test predictions
import pandas as pd
def test_predictions(model, test_img_pathnames, test_label_pathnames):
    emb_surf_pred_errors_list = []
    emb_surf_TP_list = []
    emb_surf_TN_list = []

    print("Starting testing predictions \n")

    for img_i in range(len(test_img_pathnames)):
        test_img = cv.imread(test_img_pathnames[img_i], cv.IMREAD_UNCHANGED)
        test_label = png_to_mask(cv.imread(test_label_pathnames[img_i], cv.IMREAD_UNCHANGED))

        pred_label = out_predict(model, test_img, device)

        emb_surf_pred_error = compute_emb_surf_pred_error(test_label, pred_label, print_values=False)
        
        TP, TN, _, _ = confusion(pred_label, test_label, data_type='numpy')
        emb_surf_TP_list.append(TP)
        emb_surf_TN_list.append(TN)
        
        if print_each_test_stat == True:
            print(f"Image filename {test_img_pathnames[img_i]}")
            print(f"Label filename {test_label_pathnames[img_i]}")
            print(f"Emb surf pred err={emb_surf_pred_error}%")
            print(f"Confusion values are :{confusion(pred_label, test_label, data_type='numpy')}")
        else:
            print(".", end="")
        emb_surf_pred_errors_list.append(emb_surf_pred_error)

        if img_i == len(test_img_pathnames)-1 or print_each_test_img == True:
            print("Image looks like :")
            _ , axs = plt.subplots(ncols=3, figsize=(40, 40))

            axs[0].set_title("Original image")
            axs[0].imshow(test_img)

            axs[1].set_title("Original label")
            axs[1].imshow(test_label)

            axs[2].set_title("Model predicted label")
            axs[2].imshow(pred_label)
            plt.show()
            print("\n")

    # Draw histogram with boxplot of surface error values
#     sns.set(style="ticks")
#     f, (ax_box, ax_hist) = plt.subplots(2, sharex=True, 
#                                         gridspec_kw={"height_ratios": (.15, .85)})
#     f.suptitle(f"Surface error distribution for {len(test_img_pathnames)} test images")
#     sns.boxplot(x=emb_surf_pred_errors_list, ax=ax_box)
#     sns.histplot(x=emb_surf_pred_errors_list, ax=ax_hist)
#     ax_box.set(yticks=[])
#     sns.despine(ax=ax_hist)
#     sns.despine(ax=ax_box, left=True)
#     plt.show()
#     plt.style.use('default')

    print(f"Finished testing with mean surface error={np.mean(emb_surf_pred_errors_list)}%")
    df = pd.DataFrame(data={"Emb_surf_pred_err":emb_surf_pred_errors_list, "TP": emb_surf_TP_list, "TN": emb_surf_TN_list})
    df.to_csv(f"./{model_name}.csv", sep=',',index=False)
    print("Saved CSV !")
    
test_predictions(model, test_img_pathnames, test_label_pathnames)

if train_or_load == "train":
    print("\n\nCheck of performance on training set :")
    test_predictions(model, train_img_pathnames, train_label_pathnames)
# Out:
# Starting testing predictions
#
# Image filename /home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/Session2_flushed_1-fs-13_1336.tif
# Label filename /home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/Session2_flushed_1-fs-13_1336_mask_emb.png
# Emb surf pred err=-9.341479208311045%
# Confusion values are :(0.8058616782964698, 0.9953663739289867, 0.004633626071013262, 0.19413832170353013)
# Image filename /home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/Session2_flushed_1-fs-14_799.tif
# Label filename /home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/Session2_flushed_1-fs-14_799_mask_emb.png
# Emb surf pred err=16.536654923670525%
# Confusion values are :(0.8579516859587317, 0.9942307268497093, 0.005769273150290746, 0.14204831404126825)
# Image filename /home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/Session2_flushed_1-fs-15_793.tif
# Label filename /home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/Session2_flushed_1-fs-15_793_mask_emb.png
# Emb surf pred err=-2.132249859389035%
# Confusion values are :(0.8393102257876265, 0.995447181280608, 0.00455281871939193, 0.16068977421237352)
# Image filename /home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/Session2_flushed_1-fs-16_794.tif
# Label filename /home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/Session2_flushed_1-fs-16_794_mask_emb.png
# Emb surf pred err=13.09600247318732%
# Confusion values are :(0.8549380514137594, 0.9949919293563031, 0.005008070643696938, 0.14506194858624052)
# Image filename /home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/Session2_flushed_1-fs-17_790.tif
# Label filename /home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/Session2_flushed_1-fs-17_790_mask_emb.png
# Emb surf pred err=15.087791992541565%
# Confusion values are :(0.8726886621432641, 0.9935459683030259, 0.00645403169697414, 0.1273113378567359)
# Image filename /home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/Session2_flushed_1-fs-18_788.tif
# Label filename /home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/Session2_flushed_1-fs-18_788_mask_emb.png
# Emb surf pred err=44.330638910419665%
# Confusion values are :(0.8715258553870003, 0.9911479545153574, 0.008852045484642527, 0.12847414461299966)
# Image filename /home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/Session2_flushed_1-qi-14_795.tif
# Label filename /home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/Session2_flushed_1-qi-14_795_mask_emb.png
# Emb surf pred err=7.428807263722658%
# Confusion values are :(0.8612257531985142, 0.9980335618147225, 0.00196643818527752, 0.13877424680148576)
# Image filename /home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/Session2_flushed_1-qi-15_800.tif
# Label filename /home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/Session2_flushed_1-qi-15_800_mask_emb.png
# Emb surf pred err=-0.08683269077142163%
# Confusion values are :(0.8762493059411438, 0.9982970885552425, 0.001702911444757572, 0.12375069405885619)
# Image filename /home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/Session2_flushed_1-qi-16_1525.tif
# Label filename /home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/Session2_flushed_1-qi-16_1525_mask_emb.png
# Emb surf pred err=-10.70181688635554%
# Confusion values are :(0.7820686104138508, 0.9989485157831465, 0.0010514842168535506, 0.2179313895861492)
# Image filename /home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/Session2_flushed_1-qi-18_797.tif
# Label filename /home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/Session2_flushed_1-qi-18_797_mask_emb.png
# Emb surf pred err=-7.135302253681556%
# Confusion values are :(0.8137910085054678, 0.9985919484483272, 0.0014080515516728099, 0.1862089914945322)
# Image filename /home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/Session2_flushed_1-qp-13_799.tif
# Label filename /home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/Session2_flushed_1-qp-13_799_mask_emb.png
# Emb surf pred err=23.14629258517034%
# Confusion values are :(0.8849699398797595, 0.9968717149841053, 0.0031282850158947276, 0.11503006012024049)
# Image filename /home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/Session2_flushed_1-qp-14_784.tif
# Label filename /home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/Session2_flushed_1-qp-14_784_mask_emb.png
# Emb surf pred err=18.127237039602818%
# Confusion values are :(0.9029846438055652, 0.9959252384164515, 0.004074761583548462, 0.09701535619443483)
# Image filename /home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/Session2_flushed_1-qp-15_799.tif
# Label filename /home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/Session2_flushed_1-qp-15_799_mask_emb.png
# Emb surf pred err=23.15354931347034%
# Confusion values are :(0.8963474827245804, 0.9972663247437865, 0.002733675256213439, 0.10365251727541955)
# Image filename /home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/Session2_flushed_1-qp-16_797.tif
# Label filename /home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/Session2_flushed_1-qp-16_797_mask_emb.png
# Emb surf pred err=11.219746086013885%
# Confusion values are :(0.8730638537388731, 0.9960416723459864, 0.00395832765401366, 0.12693614626112698)
# Image filename /home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/Session2_flushed_1-qp-17_785.tif
# Label filename /home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/Session2_flushed_1-qp-17_785_mask_emb.png
# Emb surf pred err=24.2326257087961%
# Confusion values are :(0.8732367964759361, 0.996523395789495, 0.003476604210504942, 0.12676320352406392)
# Image filename /home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/Session2_flushed_1-qp-18_792.tif
# Label filename /home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/Session2_flushed_1-qp-18_792_mask_emb.png
# Emb surf pred err=-21.63477028159031%
# Confusion values are :(0.031282282202738855, 0.9873567861837202, 0.012643213816279794, 0.9687177177972611)
# Image filename /home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/Session2_flushed_2-fs-13_799.tif
# Label filename /home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/Session2_flushed_2-fs-13_799_mask_emb.png
# Emb surf pred err=17.677247671545334%
# Confusion values are :(0.86186518290681, 0.9920175662600257, 0.007982433739974324, 0.13813481709319003)
# Image filename /home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/Session2_flushed_2-fs-14_1081.tif
# Label filename /home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/Session2_flushed_2-fs-14_1081_mask_emb.png
# Emb surf pred err=14.734485412439655%
# Confusion values are :(0.8325404043937592, 0.9948408394084423, 0.005159160591557758, 0.16745959560624082)
# Image filename /home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/Session2_flushed_2-fs-16_799.tif
# Label filename /home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/Session2_flushed_2-fs-16_799_mask_emb.png
# Emb surf pred err=88.76722916398299%
# Confusion values are :(0.8786551590879814, 0.9948785879469957, 0.005121412053004293, 0.12134484091201855)
# Image filename /home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/Session2_flushed_2-fs-17_924.tif
# Label filename /home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/Session2_flushed_2-fs-17_924_mask_emb.png
# Emb surf pred err=23.25830339467703%
# Confusion values are :(0.8592858713981963, 0.9916302653183209, 0.008369734681679168, 0.14071412860180366)
# Image filename /home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/Session2_flushed_2-fs-18_794.tif
# Label filename /home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/Session2_flushed_2-fs-18_794_mask_emb.png
# Emb surf pred err=7.120122598137451%
# Confusion values are :(0.873606035600613, 0.9947385173052621, 0.0052614826947379525, 0.12639396439938702)
# Image filename /home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/Session2_flushed_2-qi-14_893.tif
# Label filename /home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/Session2_flushed_2-qi-14_893_mask_emb.png
# Emb surf pred err=1.8590773467982558%
# Confusion values are :(0.8067477622217122, 0.9987903061980097, 0.0012096938019902936, 0.19325223777828782)
# Image filename /home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/Session2_flushed_2-qi-15_794.tif
# Label filename /home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/Session2_flushed_2-qi-15_794_mask_emb.png
# Emb surf pred err=2.042877116669256%
# Confusion values are :(0.8504738232095697, 0.9984260849799017, 0.001573915020098348, 0.14952617679043032)
# Image filename /home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/Session2_flushed_2-qi-16_798.tif
# Label filename /home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/Session2_flushed_2-qi-16_798_mask_emb.png
# Emb surf pred err=-0.4132231404958678%
# Confusion values are :(0.8566529492455418, 0.9989157850744196, 0.0010842149255803955, 0.14334705075445817)
# Image filename /home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/Session2_flushed_2-qi-17_800.tif
# Label filename /home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/Session2_flushed_2-qi-17_800_mask_emb.png
# Emb surf pred err=9.275010125556905%
# Confusion values are :(0.8720129607128392, 0.9981033252710156, 0.001896674728984322, 0.1279870392871608)
# Image filename /home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/Session2_flushed_2-qi-18_789.tif
# Label filename /home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/Session2_flushed_2-qi-18_789_mask_emb.png
# Emb surf pred err=9.8829776772544%
# Confusion values are :(0.8362670862425017, 0.9964574341474158, 0.0035425658525841492, 0.16373291375749827)
# Image filename /home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/Session2_flushed_2-qp-13_805.tif
# Label filename /home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/Session2_flushed_2-qp-13_805_mask_emb.png
# Emb surf pred err=11.273652037983249%
# Confusion values are :(0.8870534985184667, 0.9963314533596234, 0.0036685466403766167, 0.11294650148153333)
# Image filename /home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/Session2_flushed_2-qp-14_935.tif
# Label filename /home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/Session2_flushed_2-qp-14_935_mask_emb.png
# Emb surf pred err=7.287202506987381%
# Confusion values are :(0.8823748623697807, 0.9964384195906558, 0.003561580409344224, 0.11762513763021937)
# Image filename /home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/Session2_flushed_2-qp-15_890.tif
# Label filename /home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/Session2_flushed_2-qp-15_890_mask_emb.png
# Emb surf pred err=16.25774011825504%
# Confusion values are :(0.8891475394571442, 0.9969959709284869, 0.003004029071513078, 0.11085246054285582)
# Image filename /home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/Session2_flushed_2-qp-16_880.tif
# Label filename /home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/Session2_flushed_2-qp-16_880_mask_emb.png
# Emb surf pred err=11.621917228239777%
# Confusion values are :(0.8919309882510673, 0.9974360835844012, 0.0025639164155988724, 0.10806901174893271)
# Image filename /home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/Session2_flushed_2-qp-17_795.tif
# Label filename /home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/Session2_flushed_2-qp-17_795_mask_emb.png
# Emb surf pred err=7.156404096598812%
# Confusion values are :(0.899445478026841, 0.9972318079759603, 0.002768192024039608, 0.10055452197315896)
# Image filename /home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/Session2_flushed_2-qp-18_797.tif
# Label filename /home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/Session2_flushed_2-qp-18_797_mask_emb.png
# Emb surf pred err=2.749802622710905%
# Confusion values are :(0.8816313955055747, 0.9978305292506233, 0.0021694707493767245, 0.1183686044944253)
# Image filename /home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/Session2_flushed_3-fs-13_799.tif
# Label filename /home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/Session2_flushed_3-fs-13_799_mask_emb.png
# Emb surf pred err=15.87194608256108%
# Confusion values are :(0.8531873069362539, 0.9950685552407932, 0.004931444759206799, 0.14681269306374614)
# Image filename /home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/Session2_flushed_3-fs-14_805.tif
# Label filename /home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/Session2_flushed_3-fs-14_805_mask_emb.png
# Emb surf pred err=2.0264287555620313%
# Confusion values are :(0.8564015198215666, 0.9958313433367787, 0.0041686566632213, 0.14359848017843332)
# Image filename /home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/Session2_flushed_3-fs-15_799.tif
# Label filename /home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/Session2_flushed_3-fs-15_799_mask_emb.png
# Emb surf pred err=-6.624271330153683%
# Confusion values are :(0.8334551514442755, 0.9978394822742572, 0.0021605177257427973, 0.1665448485557245)
# Image filename /home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/Session2_flushed_3-fs-16_796.tif
# Label filename /home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/Session2_flushed_3-fs-16_796_mask_emb.png
# Emb surf pred err=21.447226916577048%
# Confusion values are :(0.8630204332462744, 0.9942415256583883, 0.005758474341611749, 0.1369795667537256)
# Image filename /home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/Session2_flushed_3-fs-17_802.tif
# Label filename /home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/Session2_flushed_3-fs-17_802_mask_emb.png
# Emb surf pred err=13.00832484877523%
# Confusion values are :(0.8306282565730371, 0.9947571017678004, 0.005242898232199574, 0.16937174342696293)
# Image filename /home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/Session2_flushed_3-fs-18_792.tif
# Label filename /home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/Session2_flushed_3-fs-18_792_mask_emb.png
# Emb surf pred err=4.339071126989282%
# Confusion values are :(0.856641766807405, 0.995634898342476, 0.004365101657523993, 0.143358233192595)
# Image filename /home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/Session2_flushed_3-qi-13_800.tif
# Label filename /home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/Session2_flushed_3-qi-13_800_mask_emb.png
# Emb surf pred err=14.376354069947384%
# Confusion values are :(0.8220365212008666, 0.997490494296578, 0.0025095057034220532, 0.1779634787991334)
# Image filename /home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/Session2_flushed_3-qi-14_800.tif
# Label filename /home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/Session2_flushed_3-qi-14_800_mask_emb.png
# Emb surf pred err=13.102791878172589%
# Confusion values are :(0.8688927664974619, 0.9981044812243274, 0.0018955187756726653, 0.13110723350253808)
# Image filename /home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/Session2_flushed_3-qi-15_805.tif
# Label filename /home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/Session2_flushed_3-qi-15_805_mask_emb.png
# Emb surf pred err=20.29527559055118%
# Confusion values are :(0.8498031496062992, 0.9975532515568357, 0.002446748443164243, 0.1501968503937008)
# Image filename /home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/Session2_flushed_3-qi-16_796.tif
# Label filename /home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/Session2_flushed_3-qi-16_796_mask_emb.png
# Emb surf pred err=-5.819515306122449%
# Confusion values are :(0.7997589272261564, 0.9988209840380319, 0.001179015961968174, 0.2002410727738436)
# Image filename /home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/Session2_flushed_3-qi-17_805.tif
# Label filename /home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/Session2_flushed_3-qi-17_805_mask_emb.png
# Emb surf pred err=-7.330526926985049%
# Confusion values are :(0.8105220449012713, 0.9988625703118157, 0.0011374296881843144, 0.1894779550987287)
# Image filename /home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/Session2_flushed_3-qi-18_799.tif
# Label filename /home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/Session2_flushed_3-qi-18_799_mask_emb.png
# Emb surf pred err=-178.33333333333334%
# Confusion values are :(0.33768825984394846, 0.9998811011828933, 0.00011889881710664225, 0.6623117401560515)
# Image filename /home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/Session2_flushed_3-qp-13_799.tif
# Label filename /home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/Session2_flushed_3-qp-13_799_mask_emb.png
# Emb surf pred err=0.1229740032957033%
# Confusion values are :(0.8469465554981677, 0.9969272127081038, 0.0030727872918961787, 0.1530534445018323)
# Image filename /home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/Session2_flushed_3-qp-14_800.tif
# Label filename /home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/Session2_flushed_3-qp-14_800_mask_emb.png
# Emb surf pred err=19.117049380207273%
# Confusion values are :(0.8627311522048364, 0.996004331267823, 0.003995668732177092, 0.13726884779516357)
# Image filename /home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/Session2_flushed_3-qp-15_797.tif
# Label filename /home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/Session2_flushed_3-qp-15_797_mask_emb.png
# Emb surf pred err=16.031642717668852%
# Confusion values are :(0.8722275071346317, 0.9956055269243577, 0.004394473075642369, 0.12777249286536824)
# Image filename /home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/Session2_flushed_3-qp-16_801.tif
# Label filename /home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/Session2_flushed_3-qp-16_801_mask_emb.png
# Emb surf pred err=1.0991990655765058%
# Confusion values are :(0.8577924244952444, 0.9964624708858223, 0.0035375291141776653, 0.14220757550475555)
# Image filename /home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/Session2_flushed_3-qp-17_813.tif
# Label filename /home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/Session2_flushed_3-qp-17_813_mask_emb.png
# Emb surf pred err=3.1712891741022373%
# Confusion values are :(0.8925102193310184, 0.9976948848570603, 0.0023051151429397026, 0.10748978066898159)
# Image filename /home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/Session2_flushed_3-qp-18_805.tif
# Label filename /home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/Session2_flushed_3-qp-18_805_mask_emb.png
# Emb surf pred err=-1.2703986779590994%
# Confusion values are :(0.8659663437021927, 0.9979209892126009, 0.002079010787399156, 0.13403365629780725)
# Image filename /home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/Session2_flushed_4-fs-13_797.tif
# Label filename /home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/Session2_flushed_4-fs-13_797_mask_emb.png
# Emb surf pred err=6.5954814766586365%
# Confusion values are :(0.8151963018425679, 0.9928814164565446, 0.007118583543455446, 0.1848036981574321)
# Image filename /home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/Session2_flushed_4-fs-14_861.tif
# Label filename /home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/Session2_flushed_4-fs-14_861_mask_emb.png
# Emb surf pred err=-7.049784707173613%
# Confusion values are :(0.8322204111677796, 0.9985514810797724, 0.0014485189202275935, 0.1677795888322204)
# Image filename /home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/Session2_flushed_4-fs-15_802.tif
# Label filename /home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/Session2_flushed_4-fs-15_802_mask_emb.png
# Emb surf pred err=-38.665938373550105%
# Confusion values are :(0.5358342794911601, 0.9962396382003486, 0.0037603617996514213, 0.4641657205088398)
# Image filename /home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/Session2_flushed_4-fs-16_795.tif
# Label filename /home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/Session2_flushed_4-fs-16_795_mask_emb.png
# Emb surf pred err=1.6093526521982464%
# Confusion values are :(0.8514520241278527, 0.9957327099483818, 0.004267290051618157, 0.14854797587214724)
# Image filename /home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/Session2_flushed_4-fs-17_800.tif
# Label filename /home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/Session2_flushed_4-fs-17_800_mask_emb.png
# Emb surf pred err=-39.03535663192316%
# Confusion values are :(0.5698662354843451, 0.9985140950411834, 0.001485904958816657, 0.4301337645156549)
# Image filename /home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/Session2_flushed_4-fs-18_799.tif
# Label filename /home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/Session2_flushed_4-fs-18_799_mask_emb.png
# Emb surf pred err=12.95579050211103%
# Confusion values are :(0.8516521860497575, 0.9910781797672004, 0.008921820232799634, 0.14834781395024252)
# Image filename /home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/Session2_flushed_4-qi-13_800.tif
# Label filename /home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/Session2_flushed_4-qi-13_800_mask_emb.png
# Emb surf pred err=-66367.0731707317%
# Confusion values are :(0.0014494614975322458, 0.999998998370683, 1.0016293170223564e-06, 0.9985505385024678)
# Image filename /home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/Session2_flushed_4-qi-14_799.tif
# Label filename /home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/Session2_flushed_4-qi-14_799_mask_emb.png
# Emb surf pred err=-218.91592920353983%
# Confusion values are :(0.2998034454850272, 0.9999036068064935, 9.639319350650087e-05, 0.7001965545149729)
# Image filename /home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/Session2_flushed_4-qi-15_786.tif
# Label filename /home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/Session2_flushed_4-qi-15_786_mask_emb.png
# Emb surf pred err=13.750250551212668%
# Confusion values are :(0.8262176788935659, 0.9980202967387799, 0.0019797032612201243, 0.17378232110643416)
# Image filename /home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/Session2_flushed_4-qi-16_799.tif
# Label filename /home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/Session2_flushed_4-qi-16_799_mask_emb.png
# Emb surf pred err=-2727400.0%
# Confusion values are :(0.0, 1.0, 0.0, 1.0)
# Image filename /home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/Session2_flushed_4-qi-17_799.tif
# Label filename /home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/Session2_flushed_4-qi-17_799_mask_emb.png
# Emb surf pred err=19.557778362727035%
# Confusion values are :(0.9165569886812319, 0.9986147158991409, 0.0013852841008591375, 0.08344301131876809)
# Image filename /home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/Session2_flushed_4-qp-13_785.tif
# Label filename /home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/Session2_flushed_4-qp-13_785_mask_emb.png
# Emb surf pred err=6.611012522182509%
# Confusion values are :(0.8823264765427778, 0.997118009910001, 0.002881990089998989, 0.11767352345722212)
# Image filename /home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/Session2_flushed_4-qp-14_794.tif
# Label filename /home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/Session2_flushed_4-qp-14_794_mask_emb.png
# Emb surf pred err=-45.24087885506954%
# Confusion values are :(0.5804535487273433, 0.9985892581411184, 0.001410741858881604, 0.4195464512726566)
# Image filename /home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/Session2_flushed_4-qp-15_1153.tif
# Label filename /home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/Session2_flushed_4-qp-15_1153_mask_emb.png
# Emb surf pred err=1.0212396110598077%
# Confusion values are :(0.8335596718996143, 0.9980657726515598, 0.0019342273484401723, 0.16644032810038567)
# Image filename /home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/Session2_flushed_4-qp-16_1037.tif
# Label filename /home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/Session2_flushed_4-qp-16_1037_mask_emb.png
# Emb surf pred err=-18.541227806199217%
# Confusion values are :(0.7564814520991336, 0.9992008396278736, 0.0007991603721263343, 0.2435185479008663)
# Image filename /home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/Session2_flushed_4-qp-17_795.tif
# Label filename /home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/Session2_flushed_4-qp-17_795_mask_emb.png
# Emb surf pred err=0.888549972647249%
# Confusion values are :(0.8488801949505164, 0.9964358222755938, 0.003564177724406198, 0.1511198050494836)
# Image filename /home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/Session2_flushed_4-qp-18_1090.tif
# Label filename /home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/Session2_flushed_4-qp-18_1090_mask_emb.png
# Emb surf pred err=13.48380148972449%
# Confusion values are :(0.8698285919411289, 0.9981917359946799, 0.0018082640053200805, 0.13017140805887104)
# Image filename /home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/Session2_flushed_5-fs-13_924.tif
# Label filename /home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/Session2_flushed_5-fs-13_924_mask_emb.png
# Emb surf pred err=6.09098298071476%
# Confusion values are :(0.860348267284057, 0.9938744176634623, 0.006125582336537673, 0.13965173271594294)
# Image filename /home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/Session2_flushed_5-fs-14_796.tif
# Label filename /home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/Session2_flushed_5-fs-14_796_mask_emb.png
# Emb surf pred err=8.471650893191036%
# Confusion values are :(0.8513937232114605, 0.9950197925026111, 0.004980207497388937, 0.14860627678853955)
# Image filename /home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/Session2_flushed_5-fs-15_805.tif
# Label filename /home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/Session2_flushed_5-fs-15_805_mask_emb.png
# Emb surf pred err=9.53885312172481%
# Confusion values are :(0.8536906722563258, 0.9956994134280175, 0.004300586571982543, 0.1463093277436742)
# Image filename /home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/Session2_flushed_5-fs-16_791.tif
# Label filename /home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/Session2_flushed_5-fs-16_791_mask_emb.png
# Emb surf pred err=-46.23844573776104%
# Confusion values are :(0.45772978667368974, 0.996273817952423, 0.0037261820475770653, 0.5422702133263102)
# Image filename /home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/Session2_flushed_5-fs-17_798.tif
# Label filename /home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/Session2_flushed_5-fs-17_798_mask_emb.png
# Emb surf pred err=-84.77077800513736%
# Confusion values are :(0.4643261074458058, 0.9983258270045182, 0.0016741729954818365, 0.5356738925541942)
# Image filename /home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/Session2_flushed_5-fs-18_800.tif
# Label filename /home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/Session2_flushed_5-fs-18_800_mask_emb.png
# Emb surf pred err=15.789122789472806%
# Confusion values are :(0.8364751570911879, 0.9898213027402358, 0.010178697259764218, 0.1635248429088121)
# Image filename /home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/Session2_flushed_5-qi-13_796.tif
# Label filename /home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/Session2_flushed_5-qi-13_796_mask_emb.png
# Emb surf pred err=8.708874758086813%
# Confusion values are :(0.8971523361902128, 0.9981821621685985, 0.0018178378314014948, 0.10284766380978712)
# Image filename /home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/Session2_flushed_5-qi-14_796.tif
# Label filename /home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/Session2_flushed_5-qi-14_796_mask_emb.png
# Emb surf pred err=-10.604756689094039%
# Confusion values are :(0.8184261715296198, 0.9989018076436544, 0.0010981923563455167, 0.1815738284703802)
# Image filename /home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/Session2_flushed_5-qi-15_795.tif
# Label filename /home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/Session2_flushed_5-qi-15_795_mask_emb.png
# Emb surf pred err=15.812057498390903%
# Confusion values are :(0.871057712937138, 0.9981641582775469, 0.0018358417224531127, 0.12894228706286204)
# Image filename /home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/Session2_flushed_5-qi-16_799.tif
# Label filename /home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/Session2_flushed_5-qi-16_799_mask_emb.png
# Emb surf pred err=14.639351259069569%
# Confusion values are :(0.8510456679470764, 0.999422526313857, 0.0005774736861430516, 0.1489543320529236)
# Image filename /home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/Session2_flushed_5-qi-17_798.tif
# Label filename /home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/Session2_flushed_5-qi-17_798_mask_emb.png
# Emb surf pred err=1.3924946896388954%
# Confusion values are :(0.840925182912438, 0.998389759485426, 0.0016102405145739947, 0.15907481708756196)
# Image filename /home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/Session2_flushed_5-qi-18_794.tif
# Label filename /home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/Session2_flushed_5-qi-18_794_mask_emb.png
# Emb surf pred err=-12.530098166327098%
# Confusion values are :(0.8005925438235536, 0.9993043197840401, 0.0006956802159599444, 0.1994074561764464)
# Image filename /home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/Session2_flushed_5-qp-13_800.tif
# Label filename /home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/Session2_flushed_5-qp-13_800_mask_emb.png
# Emb surf pred err=19.569664070490127%
# Confusion values are :(0.8806545511761467, 0.9971121692732503, 0.0028878307267496996, 0.11934544882385335)
# Image filename /home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/Session2_flushed_5-qp-15_800.tif
# Label filename /home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/Session2_flushed_5-qp-15_800_mask_emb.png
# Emb surf pred err=21.825156470825764%
# Confusion values are :(0.8342418736119523, 0.9978528490390314, 0.0021471509609685886, 0.16575812638804766)
# Image filename /home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/Session2_flushed_5-qp-16_798.tif
# Label filename /home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/Session2_flushed_5-qp-16_798_mask_emb.png
# Emb surf pred err=21.697334563285917%
# Confusion values are :(0.862601349711123, 0.9950199672091552, 0.0049800327908447635, 0.13739865028887702)
# Image filename /home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/Session2_flushed_5-qp-17_979.tif
# Label filename /home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/Session2_flushed_5-qp-17_979_mask_emb.png
# Emb surf pred err=21.865156742162892%
# Confusion values are :(0.900029998500075, 0.9971358768086582, 0.002864123191341766, 0.09997000149992501)
# Image filename /home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/Session2_flushed_5-qp-18_798.tif
# Label filename /home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/Session2_flushed_5-qp-18_798_mask_emb.png
# Emb surf pred err=-36.11059907834101%
# Confusion values are :(0.6057240881184544, 0.9986424928715434, 0.0013575071284566659, 0.3942759118815457)
# Image filename /home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/Session2_flushed_6-fs-13_799.tif
# Label filename /home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/Session2_flushed_6-fs-13_799_mask_emb.png
# Emb surf pred err=-12.791195353103026%
# Confusion values are :(0.6586436818994958, 0.9981331870071591, 0.00186681299284085, 0.34135631810050415)
# Image filename /home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/Session2_flushed_6-fs-14_803.tif
# Label filename /home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/Session2_flushed_6-fs-14_803_mask_emb.png
# Emb surf pred err=-2.2878633550105776%
# Confusion values are :(0.823946763692072, 0.9941595879582209, 0.005840412041779086, 0.176053236307928)
# Image filename /home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/Session2_flushed_6-fs-15_794.tif
# Label filename /home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/Session2_flushed_6-fs-15_794_mask_emb.png
# Emb surf pred err=18.122678332359097%
# Confusion values are :(0.833028491693851, 0.9889135175116712, 0.011086482488328754, 0.166971508306149)
# Image filename /home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/Session2_flushed_6-fs-16_797.tif
# Label filename /home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/Session2_flushed_6-fs-16_797_mask_emb.png
# Emb surf pred err=1.0192847688672826%
# Confusion values are :(0.8610358605163222, 0.9958417176623542, 0.0041582823376457665, 0.13896413948367783)
# Image filename /home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/Session2_flushed_6-fs-17_784.tif
# Label filename /home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/Session2_flushed_6-fs-17_784_mask_emb.png
# Emb surf pred err=-1.6548699032997707%
# Confusion values are :(0.8210039989975265, 0.9953100920174205, 0.004689907982579534, 0.17899600100247348)
# Image filename /home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/Session2_flushed_6-fs-18_359.tif
# Label filename /home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/Session2_flushed_6-fs-18_359_mask_emb.png
# Emb surf pred err=16.922395298945993%
# Confusion values are :(0.8297733420389889, 0.9933275150963997, 0.006672484903600309, 0.1702266579610111)
# Image filename /home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/Session2_flushed_6-qi-13_767.tif
# Label filename /home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/Session2_flushed_6-qi-13_767_mask_emb.png
# Emb surf pred err=7.775%
# Confusion values are :(0.859, 0.9980066430045699, 0.001993356995430087, 0.141)
# Image filename /home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/Session2_flushed_6-qi-14_799.tif
# Label filename /home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/Session2_flushed_6-qi-14_799_mask_emb.png
# Emb surf pred err=10.237232675002922%
# Confusion values are :(0.8588290288652565, 0.9989060671802832, 0.0010939328197168267, 0.14117097113474347)
# Image filename /home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/Session2_flushed_6-qi-15_799.tif
# Label filename /home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/Session2_flushed_6-qi-15_799_mask_emb.png
# Emb surf pred err=-5.7557732680195945%
# Confusion values are :(0.803584229390681, 0.9988742505022155, 0.0011257494977845687, 0.196415770609319)
# Image filename /home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/Session2_flushed_6-qi-16_1499.tif
# Label filename /home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/Session2_flushed_6-qi-16_1499_mask_emb.png
# Emb surf pred err=9.075946390782978%
# Confusion values are :(0.8083705619562662, 0.9987182073259627, 0.0012817926740372413, 0.19162943804373384)
# Image filename /home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/Session2_flushed_6-qi-17_799.tif
# Label filename /home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/Session2_flushed_6-qi-17_799_mask_emb.png
# Emb surf pred err=12.798965740142211%
# Confusion values are :(0.8956043956043956, 0.9983557709239013, 0.0016442290760987634, 0.1043956043956044)
# Image filename /home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/Session2_flushed_6-qi-18_799.tif
# Label filename /home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/Session2_flushed_6-qi-18_799_mask_emb.png
# Emb surf pred err=-85864.28571428571%
# Confusion values are :(0.001080182800166182, 0.9999993386037793, 6.61396220649716e-07, 0.9989198171998338)
# Image filename /home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/Session2_flushed_6-qp-13_798.tif
# Label filename /home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/Session2_flushed_6-qp-13_798_mask_emb.png
# Emb surf pred err=4.612272420768712%
# Confusion values are :(0.880782198246797, 0.9977165916498526, 0.002283408350147447, 0.11921780175320297)
# Image filename /home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/Session2_flushed_6-qp-16_798.tif
# Label filename /home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/Session2_flushed_6-qp-16_798_mask_emb.png
# Emb surf pred err=-61.82174613176503%
# Confusion values are :(0.5019253234110673, 0.9990084701492952, 0.0009915298507048845, 0.4980746765889326)
# Image filename /home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/Session2_flushed_6-qp-18_794.tif
# Label filename /home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/Session2_flushed_6-qp-18_794_mask_emb.png
# Emb surf pred err=-19.435708099731073%
# Confusion values are :(0.7587299164217838, 0.9979531410532472, 0.0020468589467528245, 0.24127008357821622)
# Image filename /home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/Session2_living_1-fs-13_789.tif
# Label filename /home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/Session2_living_1-fs-13_789_mask_emb.png
# Emb surf pred err=168.23942288945213%
# Confusion values are :(0.7496588028855528, 0.9860839902013772, 0.013916009798622859, 0.25034119711444724)
# Image filename /home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/Session2_living_1-fs-14_799.tif
# Label filename /home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/Session2_living_1-fs-14_799_mask_emb.png
# Emb surf pred err=21.018877057115198%
# Confusion values are :(0.8544288480154889, 0.9972856594185772, 0.0027143405814228313, 0.14557115198451112)
# Image filename /home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/Session2_living_1-fs-15_787.tif
# Label filename /home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/Session2_living_1-fs-15_787_mask_emb.png
# Emb surf pred err=25.69862281053617%
# Confusion values are :(0.8494451129830192, 0.9948449685167614, 0.005155031483238537, 0.1505548870169809)
# Image filename /home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/Session2_living_1-fs-16_801.tif
# Label filename /home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/Session2_living_1-fs-16_801_mask_emb.png
# Emb surf pred err=21.765557163531113%
# Confusion values are :(0.7345875542691751, 0.998635433435887, 0.0013645665641129623, 0.2654124457308249)
# Image filename /home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/Session2_living_1-fs-17_792.tif
# Label filename /home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/Session2_living_1-fs-17_792_mask_emb.png
# Emb surf pred err=29.575188548560874%
# Confusion values are :(0.7828997999076497, 0.9962426999335819, 0.0037573000664180593, 0.21710020009235032)
# Image filename /home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/Session2_living_1-fs-18_859.tif
# Label filename /home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/Session2_living_1-fs-18_859_mask_emb.png
# Emb surf pred err=3.131437989287186%
# Confusion values are :(0.4868836698255734, 0.9978777977708311, 0.002122202229168931, 0.5131163301744266)
# Image filename /home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/Session2_living_1-qi-14_796.tif
# Label filename /home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/Session2_living_1-qi-14_796_mask_emb.png
# Emb surf pred err=67.86155747836835%
# Confusion values are :(0.861557478368356, 0.9988246778532679, 0.0011753221467321244, 0.138442521631644)
# Image filename /home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/Session2_living_1-qi-15_774.tif
# Label filename /home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/Session2_living_1-qi-15_774_mask_emb.png
# Emb surf pred err=49.5114006514658%
# Confusion values are :(0.8360477741585234, 0.9992092740301882, 0.0007907259698117238, 0.16395222584147665)
# Image filename /home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/Session2_living_1-qi-16_792.tif
# Label filename /home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/Session2_living_1-qi-16_792_mask_emb.png
# Emb surf pred err=69.76976976976977%
# Confusion values are :(0.8698698698698699, 0.9988245778358303, 0.0011754221641696644, 0.13013013013013014)
# Image filename /home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/Session2_living_1-qi-18_773.tif
# Label filename /home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/Session2_living_1-qi-18_773_mask_emb.png
# Emb surf pred err=69.79472140762464%
# Confusion values are :(0.8709677419354839, 0.9996273685879647, 0.00037263141203520175, 0.12903225806451613)
# Image filename /home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/Session2_living_1-qp-13_839.tif
# Label filename /home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/Session2_living_1-qp-13_839_mask_emb.png
# Emb surf pred err=126.6355140186916%
# Confusion values are :(0.7266355140186916, 0.9991600376772174, 0.0008399623227826078, 0.2733644859813084)
# Image filename /home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/Session2_living_1-qp-14_794.tif
# Label filename /home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/Session2_living_1-qp-14_794_mask_emb.png
# Emb surf pred err=25.615550755939523%
# Confusion values are :(0.8979121670266379, 0.996973291241644, 0.003026708758355991, 0.10208783297336213)
# Image filename /home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/Session2_living_1-qp-15_850.tif
# Label filename /home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/Session2_living_1-qp-15_850_mask_emb.png
# Emb surf pred err=18.79492600422833%
# Confusion values are :(0.860676532769556, 0.9987665043785907, 0.0012334956214092767, 0.13932346723044398)
# Image filename /home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/Session2_living_1-qp-16_967.tif
# Label filename /home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/Session2_living_1-qp-16_967_mask_emb.png
# Emb surf pred err=23.880822746521478%
# Confusion values are :(0.8480036297640653, 0.9979711660613141, 0.0020288339386858745, 0.15199637023593465)
# Image filename /home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/Session2_living_1-qp-17_799.tif
# Label filename /home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/Session2_living_1-qp-17_799_mask_emb.png
# Emb surf pred err=47.450290815636414%
# Confusion values are :(0.8666305965102123, 0.9969925214568938, 0.0030074785431061886, 0.13336940348978762)
# Image filename /home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/Session2_living_1-qp-18_798.tif
# Label filename /home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/Session2_living_1-qp-18_798_mask_emb.png
# Emb surf pred err=55.80549123387364%
# Confusion values are :(0.8911677141912008, 0.9975050570241741, 0.0024949429758259084, 0.10883228580879921)
# Image filename /home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/Session2_living_2-fs-13_768.tif
# Label filename /home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/Session2_living_2-fs-13_768_mask_emb.png
# Emb surf pred err=27.229686500319897%
# Confusion values are :(0.8432501599488164, 0.9972159510312938, 0.0027840489687062267, 0.15674984005118361)
# Image filename /home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/Session2_living_2-fs-14_1109.tif
# Label filename /home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/Session2_living_2-fs-14_1109_mask_emb.png
# Emb surf pred err=43.87277829747428%
# Confusion values are :(0.6492048643592142, 0.9991845875452511, 0.0008154124547489563, 0.3507951356407858)
# Image filename /home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/Session2_living_2-fs-16_795.tif
# Label filename /home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/Session2_living_2-fs-16_795_mask_emb.png
# Emb surf pred err=63.26754385964912%
# Confusion values are :(0.8530701754385965, 0.9994667830594504, 0.000533216940549686, 0.14692982456140352)
# Image filename /home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/Session2_living_2-fs-17_753.tif
# Label filename /home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/Session2_living_2-fs-17_753_mask_emb.png
# Emb surf pred err=86.48913805185704%
# Confusion values are :(0.7829011913104414, 0.9944814492343368, 0.005518550765663177, 0.21709880868955853)
# Image filename /home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/Session2_living_2-fs-18_798.tif
# Label filename /home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/Session2_living_2-fs-18_798_mask_emb.png
# Emb surf pred err=10.555963752143033%
# Confusion values are :(0.8204751408278227, 0.999062940001594, 0.000937059998406032, 0.1795248591721773)
# Image filename /home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/Session2_living_2-qi-14_746.tif
# Label filename /home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/Session2_living_2-qi-14_746_mask_emb.png
# Emb surf pred err=57.207207207207205%
# Confusion values are :(0.7837837837837838, 0.999245939925111, 0.0007540600748889377, 0.21621621621621623)
# Image filename /home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/Session2_living_2-qi-15_794.tif
# Label filename /home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/Session2_living_2-qi-15_794_mask_emb.png
# Emb surf pred err=85.67931456548348%
# Confusion values are :(0.8531211750305998, 0.9984409757210487, 0.001559024278951271, 0.14687882496940025)
# Image filename /home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/Session2_living_2-qi-16_724.tif
# Label filename /home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/Session2_living_2-qi-16_724_mask_emb.png
# Emb surf pred err=232.43243243243242%
# Confusion values are :(0.8783783783783784, 0.9994503175099687, 0.0005496824900313107, 0.12162162162162163)
# Image filename /home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/Session2_living_2-qi-18_772.tif
# Label filename /home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/Session2_living_2-qi-18_772_mask_emb.png
# Emb surf pred err=29.42942942942943%
# Confusion values are :(0.8568568568568569, 0.9988605400049542, 0.0011394599950458261, 0.14314314314314314)
# Image filename /home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/Session2_living_2-qp-13_797.tif
# Label filename /home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/Session2_living_2-qp-13_797_mask_emb.png
# Emb surf pred err=50.13357079252003%
# Confusion values are :(0.8667260314633423, 0.9984028339612183, 0.0015971660387817015, 0.13327396853665777)
# Image filename /home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/Session2_living_2-qp-14_966.tif
# Label filename /home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/Session2_living_2-qp-14_966_mask_emb.png
# Emb surf pred err=36.19099718662082%
# Confusion values are :(0.8927008440137543, 0.9974773829991412, 0.002522617000858799, 0.1072991559862457)
# Image filename /home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/Session2_living_2-qp-15_795.tif
# Label filename /home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/Session2_living_2-qp-15_795_mask_emb.png
# Emb surf pred err=27.218132506780318%
# Confusion values are :(0.8748547074777218, 0.9989014920640702, 0.0010985079359298326, 0.12514529252227818)
# Image filename /home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/Session2_living_2-qp-16_799.tif
# Label filename /home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/Session2_living_2-qp-16_799_mask_emb.png
# Emb surf pred err=20.069204152249135%
# Confusion values are :(0.8884869455803712, 0.9993112044310548, 0.00068879556894514, 0.11151305441962882)
# Image filename /home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/Session2_living_2-qp-17_871.tif
# ...
# Label filename /home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/Session2_living_4-qi-13_800_mask_emb.png
# Emb surf pred err=-82.33830845771145%
# Confusion values are :(0.47748976807639837, 0.9999270002288262, 7.29997711737942e-05, 0.5225102319236017)
# Image filename /home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/Session2_living_4-qi-14_787.tif
# Label filename /home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/Session2_living_4-qi-14_787_mask_emb.png
# Emb surf pred err=-209.49759119064007%
# Confusion values are :(0.31109628641316434, 0.9999124926469516, 8.750735304841587e-05, 0.6889037135868357)
# Image filename /home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/Session2_living_4-qi-15_772.tif
# Label filename /home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/Session2_living_4-qi-15_772_mask_emb.png
# Emb surf pred err=90.14598540145985%
# Confusion values are :(0.7408759124087592, 0.9992224444585719, 0.0007775555414280614, 0.2591240875912409)
# Image filename /home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/Session2_living_4-qi-16_781.tif
# Label filename /home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/Session2_living_4-qi-16_781_mask_emb.png
# Emb surf pred err=-285.45454545454544%
# Confusion values are :(0.2028301886792453, 0.9999563449043589, 4.36550956410387e-05, 0.7971698113207547)
# Image filename /home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/Session2_living_4-qi-17_789.tif
# Label filename /home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/Session2_living_4-qi-17_789_mask_emb.png
# Emb surf pred err=71.42857142857143%
# Confusion values are :(0.7195767195767195, 0.9997009512295995, 0.0002990487704005345, 0.2804232804232804)
# Image filename /home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/Session2_living_4-qp-13_797.tif
# Label filename /home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/Session2_living_4-qp-13_797_mask_emb.png
# Emb surf pred err=32.8511354079058%
# Confusion values are :(0.8682926829268293, 0.9980284505538137, 0.001971549446186284, 0.13170731707317074)
# Image filename /home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/Session2_living_4-qp-14_905.tif
# Label filename /home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/Session2_living_4-qp-14_905_mask_emb.png
# Emb surf pred err=48.4472049689441%
# Confusion values are :(0.8411712511091393, 0.9977178939151182, 0.0022821060848817556, 0.15882874889086068)
# Image filename /home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/Session2_living_4-qp-15_834.tif
# Label filename /home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/Session2_living_4-qp-15_834_mask_emb.png
# Emb surf pred err=40.522504614510865%
# Confusion values are :(0.8510577878744853, 0.9983404800829973, 0.0016595199170027447, 0.1489422121255147)
# Image filename /home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/Session2_living_4-qp-16_812.tif
# Label filename /home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/Session2_living_4-qp-16_812_mask_emb.png
# Emb surf pred err=25.583552326480135%
# Confusion values are :(0.8738599474416447, 0.9985288873303919, 0.0014711126696080983, 0.12614005255835523)
# Image filename /home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/Session2_living_4-qp-17_798.tif
# Label filename /home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/Session2_living_4-qp-17_798_mask_emb.png
# Emb surf pred err=29.429159166880947%
# Confusion values are :(0.8760606839804577, 0.9976547213422521, 0.002345278657747927, 0.12393931601954229)
# Image filename /home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/Session2_living_4-qp-18_777.tif
# Label filename /home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/Session2_living_4-qp-18_777_mask_emb.png
# Emb surf pred err=59.67252880533657%
# Confusion values are :(0.8744693753790176, 0.9993530106462615, 0.0006469893537385772, 0.1255306246209824)
# Image filename /home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/Session2_living_5-fs-13_799.tif
# Label filename /home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/Session2_living_5-fs-13_799_mask_emb.png
# Emb surf pred err=-226.25893566322478%
# Confusion values are :(0.2587398967767066, 0.9992771728838886, 0.0007228271161113817, 0.7412601032232934)
# Image filename /home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/Session2_living_5-fs-14_800.tif
# Label filename /home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/Session2_living_5-fs-14_800_mask_emb.png
# Emb surf pred err=-192.96215201751642%
# Confusion values are :(0.29350843476404015, 0.9996027453136361, 0.0003972546863638782, 0.7064915652359599)
# Image filename /home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/Session2_living_5-fs-15_740.tif
# Label filename /home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/Session2_living_5-fs-15_740_mask_emb.png
# Emb surf pred err=-24.34217534888676%
# Confusion values are :(0.5794208361891706, 0.9983632663066767, 0.0016367336933232617, 0.4205791638108293)
# Image filename /home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/Session2_living_5-fs-16_798.tif
# Label filename /home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/Session2_living_5-fs-16_798_mask_emb.png
# Emb surf pred err=28.134110787172013%
# Confusion values are :(0.8008381924198251, 0.9977347968532833, 0.002265203146716787, 0.19916180758017493)
# Image filename /home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/Session2_living_5-fs-17_1011.tif
# Label filename /home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/Session2_living_5-fs-17_1011_mask_emb.png
# Emb surf pred err=-365.2574942352037%
# Confusion values are :(0.18974062448372708, 0.9996903345807943, 0.0003096654192057539, 0.8102593755162729)
# Image filename /home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/Session2_living_5-fs-18_798.tif
# Label filename /home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/Session2_living_5-fs-18_798_mask_emb.png
# Emb surf pred err=8.458993954602487%
# Confusion values are :(0.8108589027033193, 0.9948587054512548, 0.005141294548745248, 0.18914109729668074)
# Image filename /home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/Session2_living_5-qi-13_800.tif
# Label filename /home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/Session2_living_5-qi-13_800_mask_emb.png
# Emb surf pred err=38.76146788990825%
# Confusion values are :(0.863914373088685, 0.9993111915782361, 0.0006888084217639328, 0.13608562691131498)
# Image filename /home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/Session2_living_5-qi-14_799.tif
# Label filename /home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/Session2_living_5-qi-14_799_mask_emb.png
# Emb surf pred err=36.394948335246845%
# Confusion values are :(0.851894374282434, 0.9994462131408903, 0.0005537868591096697, 0.14810562571756603)
# Image filename /home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/Session2_living_5-qi-15_798.tif
# Label filename /home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/Session2_living_5-qi-15_798_mask_emb.png
# Emb surf pred err=26.848249027237355%
# Confusion values are :(0.7626459143968871, 0.9996530085493355, 0.00034699145066448864, 0.23735408560311283)
# Image filename /home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/Session2_living_5-qi-16_795.tif
# Label filename /home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/Session2_living_5-qi-16_795_mask_emb.png
# Emb surf pred err=-4.850746268656716%
# Confusion values are :(0.5231316725978647, 0.9997726533978922, 0.00022734660210774725, 0.47686832740213525)
# Image filename /home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/Session2_living_5-qi-17_798.tif
# Label filename /home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/Session2_living_5-qi-17_798_mask_emb.png
# Emb surf pred err=60.997067448680355%
# Confusion values are :(0.8152492668621701, 0.9993894182349906, 0.000610581765009384, 0.18475073313782991)
# Image filename /home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/Session2_living_5-qi-18_792.tif
# Label filename /home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/Session2_living_5-qi-18_792_mask_emb.png
# Emb surf pred err=-228.42105263157896%
# Confusion values are :(0.24465811965811965, 0.9999399598374198, 6.00401625801831e-05, 0.7553418803418803)
# Image filename /home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/Session2_living_5-qp-13_799.tif
# Label filename /home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/Session2_living_5-qp-13_799_mask_emb.png
# Emb surf pred err=-693.5294117647059%
# Confusion values are :(0.10573488779567357, 0.99981130313055, 0.00018869686944997683, 0.8942651122043265)
# Image filename /home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/Session2_living_5-qp-15_800.tif
# Label filename /home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/Session2_living_5-qp-15_800_mask_emb.png
# Emb surf pred err=-35.339922132374966%
# Confusion values are :(0.6543483071475991, 0.9996651763214798, 0.0003348236785201845, 0.345651692852401)
# Image filename /home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/Session2_living_5-qp-16_797.tif
# Label filename /home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/Session2_living_5-qp-16_797_mask_emb.png
# Emb surf pred err=-91.97635135135135%
# Confusion values are :(0.4458131690863763, 0.9996296398102482, 0.00037036018975172846, 0.5541868309136238)
# Image filename /home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/Session2_living_5-qp-17_756.tif
# Label filename /home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/Session2_living_5-qp-17_756_mask_emb.png
# Emb surf pred err=73.33962858042179%
# Confusion values are :(0.8504878816493547, 0.9987662775492863, 0.0012337224507137777, 0.14951211835064526)
# Image filename /home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/Session2_living_5-qp-18_805.tif
# Label filename /home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/Session2_living_5-qp-18_805_mask_emb.png
# Emb surf pred err=-12.05607476635514%
# Confusion values are :(0.7297748123436196, 0.9998141494238633, 0.00018585057613678603, 0.2702251876563803)
# Image filename /home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/Session2_living_6-fs-13_801.tif
# Label filename /home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/Session2_living_6-fs-13_801_mask_emb.png
# Emb surf pred err=-83.8213399503722%
# Confusion values are :(0.4430345572354212, 0.999745731484289, 0.00025426851571093884, 0.5569654427645788)
# Image filename /home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/Session2_living_6-fs-14_799.tif
# Label filename /home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/Session2_living_6-fs-14_799_mask_emb.png
# Emb surf pred err=21.821618344566883%
# Confusion values are :(0.7977960843051246, 0.9886652840793825, 0.011334715920617569, 0.20220391569487536)
# Image filename /home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/Session2_living_6-fs-15_794.tif
# Label filename /home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/Session2_living_6-fs-15_794_mask_emb.png
# Emb surf pred err=-116.87940323249067%
# Confusion values are :(0.38094510156115646, 0.9980078167305394, 0.0019921832694606, 0.6190548984388435)
# Image filename /home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/Session2_living_6-fs-16_760.tif
# Label filename /home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/Session2_living_6-fs-16_760_mask_emb.png
# Emb surf pred err=34.201465524852125%
# Confusion values are :(0.748123951620023, 0.9949634368123579, 0.0050365631876421145, 0.25187604837997707)
# Image filename /home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/Session2_living_6-fs-17_793.tif
# Label filename /home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/Session2_living_6-fs-17_793_mask_emb.png
# Emb surf pred err=-14089.285714285714%
# Confusion values are :(0.005990435439214699, 0.9999869220723657, 1.3077927634221573e-05, 0.9940095645607853)
# Image filename /home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/Session2_living_6-fs-18_1415.tif
# Label filename /home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/Session2_living_6-fs-18_1415_mask_emb.png
# Emb surf pred err=8.083636458796745%
# Confusion values are :(0.8540549027817759, 0.996505466207342, 0.0034945337926579304, 0.14594509721822416)
# Image filename /home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/Session2_living_6-qi-13_775.tif
# Label filename /home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/Session2_living_6-qi-13_775_mask_emb.png
# Emb surf pred err=39.4655704008222%
# Confusion values are :(0.8869475847893115, 0.9988937458571454, 0.0011062541428545835, 0.1130524152106886)
# Image filename /home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/Session2_living_6-qi-14_740.tif
# Label filename /home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/Session2_living_6-qi-14_740_mask_emb.png
# Emb surf pred err=21.2707182320442%
# Confusion values are :(0.7016574585635359, 0.9997944165764693, 0.0002055834235307453, 0.2983425414364641)
# Image filename /home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/Session2_living_6-qi-15_795.tif
# Label filename /home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/Session2_living_6-qi-15_795_mask_emb.png
# Emb surf pred err=21.77929022848809%
# Confusion values are :(0.8361691784151677, 0.9994028701786521, 0.0005971298213478856, 0.16383082158483228)
# Image filename /home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/Session2_living_6-qi-16_1025.tif
# Label filename /home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/Session2_living_6-qi-16_1025_mask_emb.png
# Emb surf pred err=94.7985347985348%
# Confusion values are :(0.8380952380952381, 0.9975935994510547, 0.0024064005489452343, 0.1619047619047619)
# Image filename /home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/Session2_living_6-qi-17_751.tif
# Label filename /home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/Session2_living_6-qi-17_751_mask_emb.png
# Emb surf pred err=40.04739336492891%
# Confusion values are :(0.8720379146919431, 0.9993390232660846, 0.0006609767339153683, 0.12796208530805686)
# Image filename /home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/Session2_living_6-qi-18_786.tif
# Label filename /home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/Session2_living_6-qi-18_786_mask_emb.png
# Emb surf pred err=-1860.0%
# Confusion values are :(0.05102040816326531, 1.0, 0.0, 0.9489795918367347)
# Image filename /home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/Session2_living_6-qp-13_799.tif
# Label filename /home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/Session2_living_6-qp-13_799_mask_emb.png
# Emb surf pred err=4.368588609833746%
# Confusion values are :(0.7543332154227096, 0.9988982653066034, 0.0011017346933965282, 0.2456667845772904)
# Image filename /home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/Session2_living_6-qp-16_800.tif
# Label filename /home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/Session2_living_6-qp-16_800_mask_emb.png
# Emb surf pred err=-212.1904761904762%
# Confusion values are :(0.2907260524710189, 0.9999273269970467, 7.26730029533709e-05, 0.7092739475289811)
# Image filename /home/jupyter/cs-433-project-2-ml_fools/th_analysedimages/Session2_living_6-qp-18_795.tif
# Label filename /home/jupyter/cs-433-project-2-ml_fools/th_csv_labels/png_masks_emb/Session2_living_6-qp-18_795_mask_emb.png
# Emb surf pred err=10.175497806277422%
# Confusion values are :(0.8401957475531556, 0.9979876088638688, 0.0020123911361311195, 0.1598042524468444)
# Image looks like :
# Finished testing with mean surface error=-14697.27817166258%
# Saved CSV !

# %%
# Saving the model
if train_or_load == "train":
    print(f"Remember to set a model name that makes it easy to identify")
    print(f"Here are the notebook parameters : \ncriterion={criterion} \noptimizer={optimizer} \nlr={learning_rate}, \nepochs={num_epochs}")
    
    PATH = "/content/drive/MyDrive/savedmodels/" + model_name + ".pkl"
    if env == "local" or env == "gcp":
        PATH = "./savedmodels/" + model_name + ".pkl"

    print("\nmodel_name = " + model_name)
    print("model_description = " + model_description)
    print("PATH = " + PATH)
    # Warning : only save once name and descriptions are set correctly
    torch.save({
            'name': model_name,
            'description': model_description,
            'model_state_dict': model.state_dict(),
            'optimizer_state_dict': optimizer.state_dict(), # Only needed when planning to resume training from loaded model
            }, PATH)
    print("Model saved !")
